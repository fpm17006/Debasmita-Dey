# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)
# ERROR: Operation cancelled by user

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('/content/Only negative Reviews.csv', encoding = " **ISO**-8859-1 " )
data
# Out:
#         id                                               text
# 0        1  I have return the products, but still not yet ...
# 1        2  I ordered some products on 20th January 2023. ...
# 2        3  Very bad quality products specially veggies an...
# 3        4  If we complain anything about things delivery,...
# 4        5  Been a regular user of BB. But now there are m...
# ...    ...                                                ...
# 2043  2044  Hi folks.... Worst experience with bigbasket t...
# 2044  2045  Iam a regular customer of bb daily, some thing...
# 2045  2046  I got mangoes in over ripe condition. Requeste...
# 2046  2047               But I have not received a call back.
# 2047  2048                                           Nonsense
#
# [2048 rows x 2 columns]

# %%
from collections import Counter
#from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re, string, unicodedata
import nltk
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer
nltk.download
nltk.download('wordnet')
nltk.download('stopwords')
#from nltk.tokenize import TweetTokenizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'(\\x(.){2})'
combined_pat = r'|'.join((pat1, pat2, pat3))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()
testing = data['text']
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result[0]
# Out:
# <ipython-input-6-99c4ffdbcb66>:9: MarkupResemblesLocatorWarning:
#
# The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#
# <ipython-input-6-99c4ffdbcb66>:9: MarkupResemblesLocatorWarning:
#
# The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
# 'i have return the products but still not yet received last since th jan rupee cheated not given back amount'

# %%
from pandas import DataFrame
df = DataFrame (test_result,columns=['Clean Text'])
print (df)
# Out:
#                                              Clean Text
# 0     i have return the products but still not yet r...
# 1     i ordered some products on th january out of t...
# 2     very bad quality products specially veggies an...
# 3     if we complain anything about things delivery ...
# 4     been a regular user of bb but now there are ma...
# ...                                                 ...
# 2043  hi folks worst experience with bigbasket today...
# 2044  iam a regular customer of bb daily some thing ...
# 2045  i got mangoes in over ripe condition requested...
# 2046                but i have not received a call back
# 2047                                           nonsense
#
# [2048 rows x 1 columns]

# %%
import gensim
from gensim.utils import simple_preprocess
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data = test_result
data_words = list(sent_to_words(data))
print(data_words[:1][0][:30])
# Out:
# ['have', 'return', 'the', 'products', 'but', 'still', 'not', 'yet', 'received', 'last', 'since', 'th', 'jan', 'rupee', 'cheated', 'not', 'given', 'back', 'amount']

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
# NLTK Stop words
# import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['bigbasket', 'blinkit', 'big', 'basket', 'also','bb','big basket'])
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]
def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
#!pip install spacy
import spacy
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])
# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'ADV'])
print(data_lemmatized[:1])
# Out:
# [['product', 'still', 'yet', 'last', 'amount']]

# %%
data_lemmatized
# Out:
# [['product', 'still', 'yet', 'last', 'amount'],
#  ['product',
#   'item',
#   'request',
#   'refund',
#   'back',
#   'time',
#   'refund',
#   'useless',
#   'still',
#   'money',
#   'already',
#   'day',
#   'multiple',
#   'mail',
#   'updation',
#   'clear',
#   'reckless',
#   'customer',
#   'issue',
#   'end',
#   'well',
#   'money'],
#  ['bad',
#   'quality',
#   'product',
#   'specially',
#   'fruit',
#   'bad',
#   'ask',
#   'revert',
#   'back',
#   'sometimes',
#   'issue'],
#  ['thing',
#   'delivery',
#   'sort',
#   'problem',
#   'instead',
#   'milk',
#   'veggie',
#   'fruit',
#   'properly',
#   'customer',
#   'care',
#   'namesake',
#   'thast',
#   'service',
#   'daily'],
#  ['regular',
#   'user',
#   'major',
#   'issue',
#   'payment',
#   'payment',
#   'straight',
#   'payment',
#   'successful',
#   'window',
#   'cancel',
#   'able',
#   'delivery',
#   'way'],
#  ['bad',
#   'pathetic',
#   'experience',
#   'executive',
#   'soft',
#   'skill',
#   'fool',
#   'download',
#   'subscription'],
#  ['unnecessarily',
#   'amount',
#   'delivery',
#   'charge',
#   'charge',
#   'day',
#   'delivery',
#   'charge',
#   'information',
#   'deduct',
#   'easily',
#   'facing',
#   'problem',
#   'form',
#   'past',
#   'month'],
#  ['pathetic', 'service', 'pathetic', 'customer', 'support'],
#  ['delivery',
#   'slot',
#   'fancy',
#   'message',
#   'delivery',
#   'customer',
#   'last',
#   'many',
#   'year',
#   'service',
#   'pathetic'],
#  ['delivery',
#   'man',
#   'raju',
#   'deliver',
#   'food',
#   'door',
#   'frozen',
#   'stuff',
#   'sun',
#   'time',
#   'door',
#   'second',
#   'check',
#   'list',
#   'paper',
#   'bag',
#   'stuff',
#   'inside',
#   'tear',
#   'bag',
#   'paper',
#   'flimsy',
#   'else',
#   'show',
#   'quantity',
#   'correct',
#   'packet',
#   'bad',
#   'experience',
#   'photo'],
#  ['bad', 'app', 'milk', 'time', 'check', 'site', 'fraud', 'site'],
#  ['extra',
#   'charge',
#   'customer',
#   'bad',
#   'management',
#   'bad',
#   'total',
#   'amount',
#   'taking',
#   'mean',
#   'extra',
#   'extra',
#   'char',
#   'extra',
#   'charge'],
#  ['useless',
#   'app',
#   'place',
#   'order',
#   'time',
#   'even',
#   'even',
#   'update',
#   'hour',
#   'min',
#   'order',
#   'bad',
#   'experience'],
#  ['friend',
#   'conception',
#   'unfortunately',
#   'year',
#   'probably',
#   'many',
#   'customer',
#   'customer',
#   'satisfaction'],
#  ['product',
#   'nice',
#   'deferent',
#   'team',
#   'mob',
#   'tomorrow',
#   'morning',
#   'home',
#   'able',
#   'eat',
#   'day',
#   'purple',
#   'brinjal',
#   'oder',
#   'available',
#   'time',
#   'product',
#   'end',
#   'never'],
#  ['fraud', 'company', 'customer', 'fake', 'ad', 'wrong'],
#  ['bad', 'customer', 'service', 'bad', 'refund', 'amount', 'app', 'refund'],
#  ['regular',
#   'old',
#   'customer',
#   'sad',
#   'treat',
#   'customer',
#   'order',
#   'delivery',
#   'item',
#   'recd',
#   'message',
#   'order',
#   'call',
#   'find',
#   'total',
#   'lie',
#   'fact',
#   'able',
#   'courtesy',
#   'decency',
#   'inform',
#   'apologise'],
#  ['rotten',
#   'stale',
#   'vegetable',
#   'rotten',
#   'dairy',
#   'product',
#   'rotten',
#   'frozen',
#   'product',
#   'poor',
#   'quality',
#   'grocery',
#   'supply',
#   'never',
#   'high'],
#  ['disgusting', 'hopeless', 'order', 'money', 'money', 'refunded', 'day'],
#  ['pathetic',
#   'poor',
#   'service',
#   'blot',
#   'com',
#   'business',
#   'soon',
#   'still',
#   'happy'],
#  ['fraud',
#   'firstly',
#   'bill',
#   'certain',
#   'amount',
#   'item',
#   'product',
#   'negative',
#   'balance',
#   'wallet',
#   'time',
#   'item',
#   'balance',
#   'negative',
#   'kind'],
#  ['order',
#   'product',
#   'display',
#   'process',
#   'app',
#   'last',
#   'time',
#   'order',
#   'sorry',
#   'area',
#   'servicable',
#   'last',
#   'month',
#   'order',
#   'unservisable'],
#  ['pathetic',
#   'even',
#   'order',
#   'time',
#   'term',
#   'service',
#   'order',
#   'reschedule',
#   'customer',
#   'time',
#   'kind',
#   'service',
#   'stick',
#   'close',
#   'bcoz',
#   'guy',
#   'capable',
#   'providing',
#   'order'],
#  ['disappointing',
#   'service',
#   'stuff',
#   'time',
#   'slot',
#   'informed',
#   'order',
#   'order',
#   'team',
#   'slot',
#   'available',
#   'day',
#   'value',
#   'customer',
#   'mistake'],
#  ['thing',
#   'fruit',
#   'vegetable',
#   'stale',
#   'cell',
#   'night',
#   'time',
#   'price',
#   'charge',
#   'full',
#   'rate'],
#  ['call',
#   'number',
#   'xxxx',
#   'address',
#   'wrongly',
#   'yesterday',
#   'last',
#   'day',
#   'call',
#   'respond',
#   'money',
#   'day',
#   'payment',
#   'pearl',
#   'amount',
#   'way',
#   'support',
#   'response',
#   'application',
#   'request',
#   'subscription'],
#  ['last',
#   'order',
#   'fact',
#   'king',
#   'consumer',
#   'hold',
#   'shot',
#   'order',
#   'pay',
#   'delivery',
#   'boy',
#   'order',
#   'product',
#   'less',
#   'amout',
#   'planning',
#   'haywire'],
#  ['bad',
#   'app',
#   'issue',
#   'time',
#   'update',
#   'directly',
#   'process',
#   'amount',
#   'wallet',
#   'confirmation',
#   'customer',
#   'service',
#   'customer',
#   'long',
#   'time',
#   'resolution',
#   'even',
#   'product',
#   'fresh',
#   'day'],
#  ['full',
#   'promise',
#   'service',
#   'dependable',
#   'deliver',
#   'milk',
#   'special',
#   'day',
#   'onam',
#   'special',
#   'day',
#   'customer',
#   'service',
#   'delivery',
#   'order',
#   'trust'],
#  ['staff',
#   'daily',
#   'recharge',
#   'free',
#   'milk',
#   'day',
#   'delivery',
#   'free',
#   'milk',
#   'milk',
#   'free',
#   'surprise',
#   'wallet',
#   'day',
#   'milk',
#   'delivery',
#   'executive',
#   'offer',
#   'complaint',
#   'customer',
#   'care',
#   'delivery',
#   'free',
#   'false',
#   'commitment',
#   'fake',
#   'people',
#   'proper',
#   'explanation'],
#  ['customer',
#   'service',
#   'problem',
#   'use',
#   'number',
#   'unable',
#   'payment',
#   'buggy',
#   'website',
#   'charge',
#   'problem',
#   'regular',
#   'number',
#   'revenue',
#   'telecom',
#   'provider',
#   'call',
#   'none',
#   'charge',
#   'tata',
#   'group',
#   'company'],
#  ['customer',
#   'service',
#   'bad',
#   'delivery',
#   'boy',
#   'service',
#   'bad',
#   'product',
#   'poor',
#   'response',
#   'many',
#   'time',
#   'face',
#   'issue',
#   'rating',
#   'horrible',
#   'service',
#   'overall'],
#  ['feedback', 'issue', 'time', 'row'],
#  ['really',
#   'bad',
#   'experience',
#   'order',
#   'delivery',
#   'agent',
#   'deepak',
#   'refund',
#   'multiple',
#   'time',
#   'positive',
#   'response'],
#  ['bad',
#   'experience',
#   'daily',
#   'available',
#   'placing',
#   'order',
#   'customer',
#   'support',
#   'co',
#   'operative'],
#  ['always',
#   'pack',
#   'weight',
#   'twice',
#   'faced',
#   'shortage',
#   'fresh',
#   'fish',
#   'weight',
#   'product',
#   'loose',
#   'site'],
#  ['pathetic',
#   'service',
#   'time',
#   'delivery',
#   'order',
#   'insufficient',
#   'staff',
#   'care',
#   'brand',
#   'name',
#   'srk',
#   'advertisement',
#   'delivery',
#   'nonsense',
#   'public',
#   'never'],
#  ['rd',
#   'time',
#   'order',
#   'automatically',
#   'cod',
#   'order',
#   'voucher',
#   'coupon',
#   'payment',
#   'time',
#   'convert',
#   'kind',
#   'dumb',
#   'logic',
#   'voucher',
#   'later',
#   'payment'],
#  ['well', 'fruit', 'waste', 'material', 'ripend'],
#  ['cheating', 'offer'],
#  ['delivery',
#   'boy',
#   'salary',
#   'salary',
#   'call',
#   'senior',
#   'replying',
#   'problem'],
#  ['order',
#   'charge',
#   'upto',
#   'totally',
#   'unacceptable',
#   'totally',
#   'mess',
#   'budget',
#   'sale',
#   'target'],
#  ['bad',
#   'service',
#   'full',
#   'grocery',
#   'even',
#   'full',
#   'payment',
#   'customer',
#   'care',
#   'call',
#   'even',
#   'next',
#   'hour',
#   'public'],
#  ['customer',
#   'care',
#   'many',
#   'time',
#   'never',
#   'line',
#   'always',
#   'executive',
#   'busy',
#   'bad',
#   'service'],
#  ['bad',
#   'experience',
#   'service',
#   'order',
#   'complete',
#   'never',
#   'ever',
#   'order'],
#  ['order',
#   'already',
#   'day',
#   'customer',
#   'care',
#   'people',
#   'min',
#   'call',
#   'message',
#   'side',
#   'update',
#   'order',
#   'day',
#   'day',
#   'service',
#   'bad'],
#  ['essential',
#   'service',
#   'covid',
#   'time',
#   'indifference',
#   'money',
#   'avenue',
#   'customer',
#   'convenience',
#   'min',
#   'amnt',
#   'product',
#   'time',
#   'partial',
#   'delivery',
#   'delivery',
#   'refund',
#   'difficult',
#   'parrot',
#   'system',
#   'customer',
#   'call',
#   'milk',
#   'half',
#   'time',
#   'item',
#   'material',
#   'floor',
#   'run',
#   'issue',
#   'resolution',
#   'indifferent',
#   'robot',
#   'app',
#   'goodbye',
#   'bad',
#   'service'],
#  ['milk',
#   'packet',
#   'still',
#   'delivery',
#   'boy',
#   'trouble',
#   'even',
#   'usual',
#   'bbdaily',
#   'customer',
#   'care',
#   'never',
#   'compel',
#   'complaint',
#   'bbdaily',
#   'complete',
#   'brain',
#   'shattering',
#   'experience'],
#  ['first', 'even', 'star', 'unfortunately', 'star'],
#  ['pathetic',
#   'miss',
#   'product',
#   'delivery',
#   'order',
#   'call',
#   'center',
#   'always',
#   'busy',
#   'phone',
#   'waiting',
#   'respond',
#   'time',
#   'unsuccessful',
#   'sure',
#   'cost',
#   'need'],
#  ['last',
#   'time',
#   'order',
#   'continuously',
#   'even',
#   'hour',
#   'late',
#   'team',
#   'even',
#   'inform',
#   'bout',
#   'order',
#   'order',
#   'yesterday',
#   'late',
#   'today'],
#  ['bad',
#   'app',
#   'ever',
#   'bad',
#   'service',
#   'always',
#   'damage',
#   'item',
#   'replaaement',
#   'even',
#   'truth'],
#  ['idiot',
#   'min',
#   'delivery',
#   'delivering',
#   'order',
#   'hour',
#   'service',
#   'even',
#   'worth',
#   'star',
#   'hopeless',
#   'service',
#   'bad',
#   'delivery',
#   'app'],
#  ['pathetic',
#   'service',
#   'bad',
#   'customer',
#   'support',
#   'order',
#   'daily',
#   'prior',
#   'communication',
#   'rarely',
#   'complete',
#   'item'],
#  ['regular',
#   'customer',
#   'order',
#   'item',
#   'never',
#   'multiple',
#   'time',
#   'customer',
#   'number',
#   'busy',
#   'never',
#   'thing',
#   'never',
#   'real',
#   'time',
#   'detail',
#   'executive',
#   'stupid',
#   'question',
#   'phone',
#   'number',
#   'mail',
#   'refund',
#   'delivery',
#   'never',
#   'shameful',
#   'guy',
#   'thief',
#   'loyal',
#   'customer',
#   'customer',
#   'money',
#   'old',
#   'bigbask',
#   'good',
#   'service',
#   'bad',
#   'take',
#   'item',
#   'never',
#   'refund'],
#  ['corruption', 'tata', 'product', 'bad', 'godown', 'delivery', 'pathetic'],
#  ['eatable',
#   'item',
#   'non_veg',
#   'confirmation',
#   'product',
#   'payment',
#   'surprised',
#   'item',
#   'info',
#   'nd',
#   'item',
#   'almost',
#   'half',
#   'hr',
#   'customer',
#   'care',
#   'people',
#   'free',
#   'recharged',
#   'mob',
#   'abt',
#   'mnt',
#   'even'],
#  ['fraud',
#   'first',
#   'payment',
#   'time',
#   'order',
#   'refund',
#   'transfer',
#   'wallet',
#   'future',
#   'second',
#   'time',
#   'use',
#   'amount',
#   'cancel',
#   'process',
#   'amount',
#   'wallet',
#   'fraud'],
#  ['fake',
#   'offer',
#   'order',
#   'impossible',
#   'cancel',
#   'talk',
#   'customer',
#   'care',
#   'customer',
#   'care',
#   'number',
#   'always',
#   'busy'],
#  ['service',
#   'pathetically',
#   'service',
#   'never',
#   'issue',
#   'delivery',
#   'mostly',
#   'order',
#   'apparent',
#   'reason',
#   'intimation',
#   'customer',
#   'service',
#   'order',
#   'delivery',
#   'problem',
#   'order',
#   'undelivered',
#   'money',
#   'wallet',
#   'quality',
#   'vegetable',
#   'fruit',
#   'packaging',
#   'fruit',
#   'vegetable',
#   'weight',
#   'price',
#   'information',
#   'item',
#   'time',
#   'delivery',
#   'customer',
#   'service',
#   'number'],
#  ['bad',
#   'service',
#   'fraudulent',
#   'policy',
#   'never',
#   'salesperson',
#   'place',
#   'money',
#   'lot',
#   'fake',
#   'overhere'],
#  ['service',
#   'always',
#   'order',
#   'price',
#   'pretext',
#   'never',
#   'wallet',
#   'value'],
#  ['mainly', 'indian', 'product', 'several', 'app', 'great', 'shopping', 'app'],
#  ['money', 'account', 'inactive', 'following', 'long', 'fraudulent', 'policy'],
#  ['negative',
#   'rating',
#   'horrible',
#   'time',
#   'always',
#   'frustrated',
#   'deal',
#   'company',
#   'back',
#   'chance',
#   'ala',
#   'late',
#   'order',
#   'couple',
#   'hour',
#   'delivery',
#   'half',
#   'order',
#   'available',
#   'stuff',
#   'website',
#   'people',
#   'concept',
#   'inventory',
#   'management',
#   'foreign',
#   'working',
#   'past',
#   'item',
#   'often',
#   'veggie',
#   'bakery',
#   'item',
#   'stale',
#   'sometimes',
#   'even',
#   'rotten',
#   'prompt',
#   'extra',
#   'even',
#   'extra',
#   'veggie',
#   'item',
#   'sometimes',
#   'even',
#   'apologize',
#   'item',
#   'high',
#   'grocery',
#   'store',
#   'novelty',
#   'shopping',
#   'product',
#   'worth',
#   'never'],
#  ['really',
#   'bad',
#   'company',
#   'item',
#   'order',
#   'due',
#   'problem',
#   'money',
#   'hour',
#   'hour',
#   'still'],
#  ['product', 'order', 'blind', 'last', 'year', 'product', 'careless'],
#  ['kindly',
#   'today',
#   'order',
#   'worth',
#   'change',
#   'rs',
#   'delivery',
#   'person',
#   'credit',
#   'balance',
#   'rs',
#   'wallet',
#   'customer',
#   'care',
#   'mail',
#   'proper',
#   'response',
#   'cheap'],
#  ['prepaid',
#   'item',
#   'half',
#   'hour',
#   'delivery',
#   'slot',
#   'order',
#   'customer',
#   'support',
#   'team',
#   'resolve',
#   'issue',
#   'closing',
#   'chat',
#   'call',
#   'fraustered',
#   'unreliable',
#   'get',
#   'order',
#   'product',
#   'first',
#   'order',
#   'bad',
#   'experience',
#   'alll',
#   'service',
#   'willing',
#   'single',
#   'point'],
#  ['order', 'convenience'],
#  ['item',
#   'fully',
#   'bad',
#   'smell',
#   'horribly',
#   'caution',
#   'wind',
#   'customer',
#   'badly',
#   'customer',
#   'person',
#   'item',
#   'notice',
#   'never',
#   'onwards'],
#  ['daily',
#   'milk',
#   'butter',
#   'milk',
#   'last',
#   'day',
#   'milk',
#   'subscription',
#   'cow',
#   'milk',
#   'milk',
#   'essential',
#   'product',
#   'unfortunately',
#   'last',
#   'day',
#   'product',
#   'stock',
#   'update',
#   'app',
#   'product',
#   'available',
#   'app',
#   'hence',
#   'last',
#   'day'],
#  ['regular',
#   'customer',
#   'dissapointment',
#   'order',
#   'individually',
#   'many',
#   'time',
#   'problem',
#   'comfort',
#   'conditioner',
#   'sale',
#   'con',
#   'beware',
#   'customer'],
#  ['unable',
#   'proper',
#   'contact',
#   'deiverie',
#   'customer',
#   'delivery',
#   'proper',
#   'carry',
#   'bag'],
#  ['bad', 'experience', 'first', 'time', 'order', 'vegetable', 'item', 'poor'],
#  ['pathetic',
#   'online',
#   'app',
#   'ever',
#   'express',
#   'delivery',
#   'order',
#   'prior',
#   'intimation',
#   'notification',
#   'cancel',
#   'msg',
#   'hrs',
#   'placing',
#   'order',
#   'right',
#   'guest',
#   'table',
#   'customer',
#   'care',
#   'initially',
#   'lame',
#   'excuse',
#   'later',
#   'informed',
#   'aloted',
#   'far',
#   'location',
#   'place',
#   'order',
#   'hrs',
#   'order',
#   'professionalism',
#   'ethic'],
#  ['bbdaily',
#   'time',
#   'delivery',
#   'man',
#   'bell',
#   'day',
#   'onward',
#   'issue',
#   'poor',
#   'service',
#   'app',
#   'kind',
#   'help',
#   'disgusting'],
#  ['never',
#   'thing',
#   'order',
#   'first',
#   'place',
#   'order',
#   'order',
#   'order',
#   'finally',
#   'status',
#   'order',
#   'contact',
#   'customer',
#   'service',
#   'sorry',
#   'tech',
#   'error',
#   'bangalore',
#   'unprofessional',
#   'use',
#   'service'],
#  ['bad',
#   'experience',
#   'order',
#   'never',
#   'status',
#   'show',
#   'customer',
#   'care',
#   'guy',
#   'wrong',
#   'wrong',
#   'address'],
#  ['dunzo',
#   'congratulation',
#   'pathetic',
#   'service',
#   'ordering',
#   'last',
#   'day',
#   'order',
#   'time',
#   'hour',
#   'order',
#   'delivery',
#   'possible',
#   'delivery',
#   'possible',
#   'cart',
#   'open',
#   'fool',
#   'customer',
#   'order',
#   'message',
#   'option'],
#  ['rupee',
#   'hacker',
#   'account',
#   'fraudster',
#   'able',
#   'use',
#   'account',
#   'use',
#   'account',
#   'issue',
#   'gift',
#   'card',
#   'use',
#   'surprisingly',
#   'pin',
#   'mobile',
#   'inspite',
#   'ready',
#   'flaw',
#   'system',
#   'link',
#   'payment',
#   'method',
#   'open',
#   'hacking'],
#  ['regular', 'customer', 'bangalore', 'service', 'short'],
#  ['always',
#   'problem',
#   'coupon',
#   'payment',
#   'payment',
#   'always',
#   'confirm',
#   'order',
#   'payment',
#   'message',
#   'time',
#   'switch',
#   'grocery'],
#  ['chicken',
#   'leg',
#   'piece',
#   'greenish',
#   'dangerous',
#   'health',
#   'option',
#   'literally'],
#  ['shopping',
#   'hub',
#   'recently',
#   'oil',
#   'tin',
#   'bad',
#   'experience',
#   'least',
#   'message',
#   'friend',
#   'family',
#   'mistake',
#   'indian',
#   'company',
#   'amazon',
#   'other',
#   'people',
#   'business',
#   'customer',
#   'executive',
#   'olden',
#   'day',
#   'government',
#   'employee',
#   'arrogant'],
#  ['regular', 'customer', 'order', 'early', 'pepper', 'sauce'],
#  [],
#  ['customer',
#   'support',
#   'solution',
#   'payment',
#   'issue',
#   'discount',
#   'voucher',
#   'never',
#   'payment',
#   'discount',
#   'voucher',
#   'bank',
#   'mostly',
#   'customer',
#   'business',
#   'bad',
#   'service'],
#  ['pathetic',
#   'bad',
#   'bad',
#   'quality',
#   'customer',
#   'care',
#   'experience',
#   'reason'],
#  ['cheater', 'people', 'never', 'good', 'time', 'worst', 'bad'],
#  ['capacity', 'painful', 'experience', 'material', 'watchman'],
#  ['highly',
#   'low',
#   'quality',
#   'product',
#   'kindly',
#   'time',
#   'value',
#   'money',
#   'cheap',
#   'product'],
#  ['bad'],
#  ['really',
#   'awful',
#   'app',
#   'first',
#   'show',
#   'time',
#   'later',
#   'call',
#   'sorry',
#   'delivery',
#   'possible',
#   'thrice',
#   'time'],
#  ['always',
#   'satisfied',
#   'quality',
#   'food',
#   'deliver',
#   'infact',
#   'many',
#   'time',
#   'service',
#   'really',
#   'bad'],
#  ['delivery',
#   'staff',
#   'contact',
#   'delivery',
#   'item',
#   'physically',
#   'item',
#   'item',
#   'house',
#   'scary',
#   'covid',
#   'protocol',
#   'place'],
#  ['order',
#   'week',
#   'ago',
#   'yet',
#   'order',
#   'order',
#   'status',
#   'multiple',
#   'time',
#   'customer',
#   'service',
#   'call',
#   'even',
#   'window',
#   'want'],
#  ['people',
#   'delivery',
#   'agent',
#   'properly',
#   'people',
#   'basket',
#   'thing',
#   'fast',
#   'rate',
#   'instantly',
#   'away'],
#  ['bad',
#   'website',
#   'bad',
#   'place',
#   'shop',
#   'item',
#   'cart',
#   'lot',
#   'item',
#   'available',
#   'stock',
#   'priority',
#   'slot',
#   'start',
#   'member',
#   'customer',
#   'service',
#   'web'],
#  ['non',
#   'delivery',
#   'good',
#   'advance',
#   'everytime',
#   'call',
#   'apologize',
#   'tomorrow',
#   'tomorrow',
#   'never',
#   'bad',
#   'part',
#   'transaction',
#   'however',
#   'delivery',
#   'person',
#   'brand',
#   'small',
#   'hawker',
#   'well',
#   'cheater'],
#  ['customer',
#   'service',
#   'drastically',
#   'proper',
#   'guidance',
#   'delivery',
#   'boy',
#   'online',
#   'payment',
#   'multiple',
#   'time',
#   'reschedule',
#   'order',
#   'customer',
#   'product',
#   'however',
#   'due',
#   'unavailability',
#   'payment',
#   'option',
#   'online',
#   'stock',
#   'slot',
#   'customer',
#   'service'],
#  ['product',
#   'nuts',
#   'pack',
#   'white',
#   'insect',
#   'brown',
#   'insect',
#   'sesame',
#   'seed',
#   'dark',
#   'back',
#   'spot',
#   'almost',
#   'seed',
#   'really',
#   'bad',
#   'experience',
#   'purchase',
#   'product',
#   'life',
#   'well',
#   'local',
#   'market',
#   'people',
#   'offline',
#   'purchase',
#   'enough',
#   'time',
#   'return',
#   'product',
#   'amount',
#   'extra',
#   'pickup',
#   'product',
#   'really',
#   'people',
#   'time',
#   'product',
#   'dustbin'],
#  ['product',
#   'good',
#   'time',
#   'bad',
#   'street',
#   'shop',
#   'quality',
#   'even',
#   'wise',
#   'worth',
#   'service',
#   'last',
#   'attempt',
#   'mistake',
#   'poor',
#   'service',
#   'everytime',
#   'mango',
#   'ginger',
#   'pickle',
#   'charge',
#   'extra',
#   'vary',
#   'weight',
#   'never',
#   'refund',
#   'anytime'],
#  ['order',
#   'time',
#   'order',
#   'acceptance',
#   'bad',
#   'still',
#   'item',
#   'payment',
#   'channel',
#   'pathetic',
#   'time',
#   'payment',
#   'even',
#   'option',
#   'automatically',
#   'cash',
#   'delivery',
#   'mode',
#   'service',
#   'boy',
#   'arogent',
#   'bad',
#   'language'],
#  ['site', 'highly', 'unreliable', 'week', 'order'],
#  ['bad',
#   'experience',
#   'bad',
#   'online',
#   'grocery',
#   'store',
#   'never',
#   'delivery',
#   'slot',
#   'everytime',
#   'show',
#   'slot',
#   'available'],
#  ['customer',
#   'late',
#   'system',
#   'inefficient',
#   'call',
#   'center',
#   'support',
#   'whatsoever',
#   'able',
#   'place',
#   'order',
#   'month',
#   'time',
#   'complaint',
#   'resolution',
#   'grocery',
#   'delivery',
#   'platform'],
#  ['time', 'spoiled', 'chicken', 'customer', 'late', 'date', 'meat', 'fraud'],
#  ['recently',
#   'vegetable',
#   'juice',
#   'application',
#   'order',
#   'day',
#   'vegetable',
#   'fresh',
#   'vegetable',
#   'dried',
#   'juice',
#   'packet',
#   'call',
#   'customer',
#   'service',
#   'refund',
#   'money',
#   'replace',
#   'product',
#   'reply',
#   'fresh',
#   'material',
#   'customer',
#   'service',
#   'good',
#   'product',
#   'quality',
#   'fresh'],
#  ['last',
#   'month',
#   'quality',
#   'product',
#   'simply',
#   'awful',
#   'yogurt',
#   'rotten',
#   'vegetable',
#   'time',
#   'pack',
#   'frozen',
#   'berry',
#   'company',
#   'month',
#   'back',
#   'product',
#   'shameful',
#   'bad',
#   'experience',
#   'simple',
#   'old',
#   'product',
#   'money',
#   'horrible',
#   'company',
#   'poor',
#   'service'],
#  ['delivery',
#   'item',
#   'last',
#   'consecutive',
#   'order',
#   'many',
#   'order',
#   'item',
#   'mostly',
#   'meat',
#   'fish',
#   'pride',
#   'refund',
#   'absolutely',
#   'rubbish',
#   'experience',
#   'last',
#   'moment',
#   'item'],
#  ['mostly',
#   'grocery',
#   'resolve',
#   'problem',
#   'sometimes',
#   'bad',
#   'quality',
#   'veggie',
#   'time',
#   'delivery'],
#  ['time',
#   'mrp',
#   'worth',
#   'product',
#   'issue',
#   'replace',
#   'product',
#   'high',
#   'mrp',
#   'sticker',
#   'customer',
#   'app'],
#  ['unethical', 'issue'],
#  ['black', 'spot', 'spray', 'customer', 'quality', 'primarily', 'service'],
#  ['many',
#   'product',
#   'price',
#   'expensive',
#   'cancel',
#   'order',
#   'time',
#   'unreliable',
#   'service',
#   'always',
#   'well',
#   'kind',
#   'company'],
#  ['bad',
#   'experience',
#   'fake',
#   'promise',
#   'time',
#   'week',
#   'guy',
#   'stock',
#   'product',
#   'customer',
#   'pls',
#   'order',
#   'bad'],
#  ['papaya',
#   'fruit',
#   'handover',
#   'security',
#   'even',
#   'major',
#   'cut',
#   'body',
#   'really',
#   'poor',
#   'quality',
#   'much',
#   'worth',
#   'online',
#   'especially',
#   'highly'],
#  ['today',
#   'occasion',
#   'dussehra',
#   'gram',
#   'mutton',
#   'pack',
#   'day',
#   'old',
#   'smelly',
#   'non_veg',
#   'item',
#   'expiry_date',
#   'food',
#   'smelly',
#   'date',
#   'sepr',
#   'basic'],
#  ['bad',
#   'ever',
#   'never',
#   'overseas',
#   'order',
#   'elderly',
#   'mum',
#   'poor',
#   'experience',
#   'grape',
#   'spoilt',
#   'carton',
#   'milk',
#   'day',
#   'likewise',
#   'product',
#   'soon',
#   'order',
#   'money',
#   'deliberately',
#   'available',
#   'back',
#   'use',
#   'money',
#   'pay',
#   'pay',
#   'delivery',
#   'charge',
#   'time',
#   'back',
#   'almost',
#   'order',
#   'hospital',
#   'bill',
#   'family',
#   'sick',
#   'due',
#   'poor',
#   'quality',
#   'first',
#   'last'],
#  ['pathetic',
#   'wallet',
#   'order',
#   'direct',
#   'transfer',
#   'secondly',
#   'change',
#   'feed',
#   'address',
#   'daily',
#   'custimer',
#   'care',
#   'executive',
#   'issue',
#   'try',
#   'issue'],
#  ['brand', 'poor', 'quality', 'vegetable', 'guy', 'home', 'threaten', 'force'],
#  ['bad', 'service', 'experience'],
#  ['pathetic',
#   'app',
#   'day',
#   'free',
#   'delivery',
#   'milk',
#   'day',
#   'free',
#   'milk',
#   'non',
#   'delivery',
#   'milk',
#   'subscription',
#   'free',
#   'delivery',
#   'app',
#   'past',
#   'many',
#   'day',
#   'delete',
#   'subscription',
#   'excuse',
#   'side',
#   'abruptly',
#   'session',
#   'fake',
#   'app',
#   'fake',
#   'offer'],
#  ['fake',
#   'product',
#   'item',
#   'unhygienic',
#   'delivery',
#   'improvement',
#   'complaint'],
#  ['grocery',
#   'cod',
#   'option',
#   'card',
#   'amount',
#   'grocery',
#   'hat',
#   'payment',
#   'pay',
#   'twice',
#   'sked',
#   'cancel',
#   'order',
#   'order',
#   'sms',
#   'email',
#   'cancellation',
#   'never',
#   'transaction',
#   'customer',
#   'support',
#   'payment',
#   'stuck',
#   'intermediary',
#   'never',
#   'raise',
#   'dispute',
#   'proof',
#   'transaction',
#   'cash',
#   'sep',
#   'refund',
#   'order',
#   'cancellation',
#   'time',
#   'customer',
#   'support',
#   'different',
#   'answer',
#   'never',
#   'problem'],
#  ['fruit', 'ever', 'poor', 'quality'],
#  ['green',
#   'hard',
#   'substance',
#   'package',
#   'product',
#   'packaging',
#   'precaution',
#   'pandemic',
#   'safe',
#   'option',
#   'online',
#   'purchasing',
#   'grocery'],
#  ['member',
#   'year',
#   'well',
#   'downwards',
#   'gradually',
#   'yesterday',
#   'order',
#   'today',
#   'slot',
#   'call',
#   'bike',
#   'close',
#   'house',
#   'shortly',
#   'wrong',
#   'minute',
#   'message',
#   'product',
#   'possible',
#   'security',
#   'personnel',
#   'coimbatore',
#   'depot',
#   'person',
#   'always',
#   'busy',
#   'telephone',
#   'continuous',
#   'call',
#   'person',
#   'phone',
#   'automatically',
#   'totally',
#   'upset',
#   'unprofessional',
#   'behavior',
#   'whole',
#   'thing',
#   'app',
#   'show',
#   'difficult',
#   'cancel',
#   'individual',
#   'product',
#   'next',
#   'scam',
#   'slot',
#   'pick',
#   'whole',
#   'thing',
#   'scam',
#   'review',
#   'good',
#   'service',
#   'complaint'],
#  ['customer',
#   'service',
#   'rediculous',
#   'comfort',
#   'timing',
#   'first',
#   'early',
#   'slot',
#   'lame',
#   'excuse',
#   'reschedule',
#   'different',
#   'schedule'],
#  ['time', 'article', 'bad', 'shape', 'time', 'partially', 'rotten', 'grape'],
#  ['bbdaily',
#   'month',
#   'deduct',
#   'money',
#   'reason',
#   'sometimes',
#   'wrong',
#   'item',
#   'incorrectly',
#   'account',
#   'year',
#   'call',
#   'back',
#   'good',
#   'service',
#   'place',
#   'purchase'],
#  ['membership',
#   'back',
#   'never',
#   'prime',
#   'membership',
#   'slot',
#   'finally',
#   'today',
#   'membership',
#   'back'],
#  ['rotten',
#   'foul',
#   'fish',
#   'waste',
#   'money',
#   'unknowingly',
#   'producti',
#   'return',
#   'fish',
#   'lover',
#   'early',
#   'irritated',
#   'customer',
#   'stale',
#   'product',
#   'even',
#   'fresh',
#   'lime',
#   'rotten',
#   'bad',
#   'delivery',
#   'delivery',
#   'guy',
#   'detergent',
#   'grocery',
#   'bread',
#   'suitable',
#   'consume',
#   'grocery',
#   'business',
#   'shame'],
#  ['combo', 'pack', 'pack', 'poor', 'service', 'sowing', 'list'],
#  ['horrible',
#   'management',
#   'even',
#   'fit',
#   'work',
#   'tea',
#   'especially',
#   'arvind',
#   'king',
#   'job',
#   'applicant',
#   'slave',
#   'pandemic',
#   'enormous',
#   'crowd',
#   'applicant',
#   'office',
#   'foot',
#   'people',
#   'city',
#   'market',
#   'professionality',
#   'good',
#   'part',
#   'people',
#   'mask',
#   'idea',
#   'basic',
#   'knowledge',
#   'current',
#   'pandemic',
#   'situation',
#   'bad',
#   'part',
#   'even',
#   'many',
#   'people',
#   'hard',
#   'copy',
#   'resume',
#   'instead',
#   'soft',
#   'copy',
#   'people',
#   'hr',
#   'team',
#   'even',
#   'applicant',
#   'personal',
#   'laptop',
#   'view',
#   'limited',
#   'power',
#   'supply',
#   'company',
#   'printer',
#   'hence',
#   'security',
#   'guard',
#   'nearby',
#   'printout',
#   'resume',
#   'even',
#   'nearby',
#   'cyber',
#   'away',
#   'many',
#   'due',
#   'pandemic',
#   'crisis',
#   'hard',
#   'copy'],
#  ['complacent',
#   'inefficient',
#   'useless',
#   'day',
#   'back',
#   'order',
#   'day',
#   'delivery',
#   'product',
#   'important',
#   'rush',
#   'market',
#   'even',
#   'day',
#   'today',
#   'daughter',
#   'order',
#   'useless',
#   'company'],
#  ['interview',
#   'bad',
#   'even',
#   'thing',
#   'candidate',
#   'person',
#   'owner',
#   'company',
#   'even',
#   'ready',
#   'answer',
#   'ready'],
#  ['item', 'security', 'seperately', 'cover', 'bag', 'unsafe', 'covid', 'time'],
#  ['recent',
#   'experience',
#   'grocery',
#   'giant',
#   'practically',
#   'horrible',
#   'way',
#   'helpless',
#   'query',
#   'update',
#   'mobile',
#   'number',
#   'link',
#   'active',
#   'account',
#   'possible',
#   'transfer',
#   'wallet',
#   'amount',
#   'account',
#   'impossible',
#   'really',
#   'money',
#   'minded',
#   'people',
#   'pathetic',
#   'customer',
#   'service',
#   'even',
#   'penny',
#   'forward',
#   'money',
#   'wallet',
#   'donation',
#   'bangalore',
#   'extremely',
#   'bad',
#   'experience',
#   'grocery',
#   'shopping',
#   'giant'],
#  ['time',
#   'usually',
#   'careless',
#   'constant',
#   'change',
#   'price',
#   'item',
#   'price',
#   'item',
#   'forcibly',
#   'item',
#   'quantity',
#   'vegetable',
#   'charge',
#   'product',
#   'lot',
#   'fraud',
#   'cheating'],
#  ['thing',
#   'worth',
#   'rupee',
#   'hr',
#   'time',
#   'item',
#   'cart',
#   'stock',
#   'fine',
#   'continued',
#   'item',
#   'pay',
#   'pay',
#   'instead',
#   'automatically',
#   'option',
#   'cash',
#   'delivery',
#   'customer',
#   'care',
#   'reason',
#   'order',
#   'reorder',
#   'vain',
#   'online',
#   'find',
#   'issue',
#   'time',
#   'girl',
#   'smart',
#   'guideline',
#   'use',
#   'coupon',
#   'code',
#   'actually',
#   'due',
#   'coupon',
#   'code',
#   'payment',
#   'still',
#   'payment',
#   'time',
#   'pay',
#   'trust',
#   'site',
#   'morning',
#   'message',
#   'order',
#   'next',
#   'second',
#   'message',
#   'order',
#   'person',
#   'doorstep',
#   'fun',
#   'phone',
#   'first',
#   'people'],
#  ['car', 'complaint', 'simply', 'neighbour', 'cctv', 'footage', 'correctly'],
#  ['low', 'quality', 'rice', 'name', 'miniket', 'hire', 'market', 'price'],
#  ['permanent',
#   'customer',
#   'time',
#   'delivery',
#   'company',
#   'continuesly',
#   'sudden',
#   'cancellation',
#   'hell',
#   'lot',
#   'problem'],
#  ['amount', 'account'],
#  ['service',
#   'good',
#   'good',
#   'available',
#   'intimate',
#   'long',
#   'time',
#   'service'],
#  ['customer',
#   'care',
#   'never',
#   'arrogant',
#   'keeper',
#   'customer',
#   'friendly',
#   'fruit',
#   'inferior',
#   'quality'],
#  ['bigbasketdaily',
#   'daily',
#   'ninja',
#   'buy',
#   'customer',
#   'service',
#   'bug',
#   'bad',
#   'today',
#   'milk',
#   'delivery',
#   'app',
#   'option',
#   'mark',
#   'order',
#   'customer',
#   'care',
#   'reachable'],
#  ['order',
#   'notification',
#   'customer',
#   'downstairs',
#   'collect',
#   'order',
#   'bag',
#   'door',
#   'customer',
#   'delivery',
#   'boy',
#   'time',
#   'span',
#   'min',
#   'call',
#   'back',
#   'next',
#   'min',
#   'order',
#   'still',
#   'way',
#   'end',
#   'slot',
#   'connect',
#   'delivery',
#   'exec',
#   'order',
#   'time',
#   'pick',
#   'call',
#   'even',
#   'reschedule',
#   'order',
#   'update',
#   'late',
#   'bad',
#   'delivery',
#   'service',
#   'ever',
#   'even',
#   'contact',
#   'delivery',
#   'exec',
#   'beforehand',
#   'disappoint'],
#  ['rude',
#   'shock',
#   'horrible',
#   'vegetable',
#   'ready',
#   'refund',
#   'waste',
#   'time',
#   'energy'],
#  ['capsicum',
#   'half',
#   'andnoddle',
#   'magic',
#   'masala',
#   'order',
#   'magic',
#   'masala',
#   'capsicum',
#   'rate',
#   'capsicum',
#   'rate',
#   'show',
#   'big',
#   'cheater',
#   'customer'],
#  ['sodexo', 'meal', 'card', 'order'],
#  ['bbdaily', 'management', 'pathetic', 'concerned', 'customer'],
#  ['manipulate',
#   'billing',
#   'repeatedly',
#   'undelivered',
#   'item',
#   'instead',
#   'wallet',
#   'balance',
#   'wallet',
#   'balance'],
#  ['due',
#   'lock',
#   'grocery',
#   'vegetable',
#   'rave',
#   'sooji',
#   'insect',
#   'cockroach',
#   'smell'],
#  ['order',
#   'order',
#   'item',
#   'respect',
#   'customer',
#   'privacy',
#   'surprise',
#   'order',
#   'totally',
#   'unpacked',
#   'left',
#   'floor',
#   'security',
#   'room',
#   'society',
#   'delivery',
#   'man',
#   'message',
#   'stuff',
#   'surprise',
#   'item',
#   'society',
#   'delivery',
#   'guy',
#   'numberless',
#   'contact',
#   'customer',
#   'care',
#   'online',
#   'response',
#   'side',
#   'chat',
#   'agent',
#   'busy',
#   'whole',
#   'day',
#   'extra',
#   'delivery',
#   'less',
#   'stuff',
#   'item',
#   'already',
#   'society',
#   'gate',
#   'totally',
#   'unpacked',
#   'wonder',
#   'charge',
#   'much',
#   'unprofessional',
#   'attitude',
#   'close',
#   'question',
#   'customer',
#   'care',
#   'section',
#   'customer',
#   'directly',
#   'contact',
#   'instead',
#   'even',
#   'reply',
#   'humiliating',
#   'experience',
#   'even',
#   'sure',
#   'money',
#   'item',
#   'delivery',
#   'guy',
#   'unethical',
#   'stuff',
#   'society',
#   'gate',
#   'never',
#   'ever',
#   'wonder',
#   'name',
#   'trust'],
#  ['terrible',
#   'experience',
#   'delivery',
#   'msg',
#   'item',
#   'order',
#   'pack',
#   'delivery',
#   'online',
#   'customer',
#   'service',
#   'single',
#   'day',
#   'bad',
#   'person',
#   'entire',
#   'complaint',
#   'unprofessional',
#   'annoying',
#   'amount',
#   'item',
#   'unacceptable',
#   'yesterday',
#   'undelivered',
#   'pack',
#   'milk',
#   'min',
#   'obviously',
#   'delivery',
#   'back',
#   'tell',
#   'normal',
#   'simply',
#   'refunded',
#   'amount',
#   'today',
#   'due',
#   'security',
#   'restriction',
#   'doorstep',
#   'many',
#   'milkman',
#   'promise',
#   'hour',
#   'hope'],
#  ['item', 'price', 'item', 'vegetable', 'list', 'instead', 'full', 'refund'],
#  ['company',
#   'bill',
#   'product',
#   'order',
#   'number',
#   'mbo',
#   'money',
#   'wallet',
#   'mercy',
#   'complaint',
#   'many',
#   'time',
#   'response'],
#  ['opinion',
#   'skip',
#   'app',
#   'always',
#   'customer',
#   'service',
#   'team',
#   'idea',
#   'matter',
#   'solution'],
#  ['rotten', 'vegetable'],
#  ['review',
#   'terrible',
#   'recent',
#   'experience',
#   'user',
#   'even',
#   'delivery',
#   'boy',
#   'website',
#   'address',
#   'else',
#   'suddenly',
#   'day',
#   'grocery',
#   'leave',
#   'inform',
#   'item',
#   'particular',
#   'day'],
#  ['worst',
#   'money',
#   'bad',
#   'quality',
#   'bad',
#   'condition',
#   'image',
#   'lot',
#   'brand_ambassador',
#   'shiiit'],
#  ['review', 'recent', 'terrible', 'experience'],
#  ['first',
#   'proper',
#   'order',
#   'item',
#   'customer',
#   'service',
#   'hour',
#   'pathetic',
#   'service'],
#  ['worse'],
#  ['brand',
#   'fresho',
#   'egg',
#   'lockdown',
#   'plastic',
#   'omlette',
#   'ban',
#   'fresho',
#   'highly',
#   'unacceptable',
#   'dangerous',
#   'health',
#   'money',
#   'customer',
#   'plastic',
#   'even',
#   'almost',
#   'pathetic',
#   'quality',
#   'service',
#   'sure',
#   'quality',
#   'check',
#   'product'],
#  ['disgraceful',
#   'service',
#   'request',
#   'yet',
#   'sms',
#   'request',
#   'reaction',
#   'crate',
#   'reaction',
#   'versatile',
#   'conveyance',
#   'person',
#   'noticeably',
#   'terrible',
#   'however',
#   'last',
#   'involvement',
#   'bushel'],
#  ['bad',
#   'experience',
#   'app',
#   'webportal',
#   'daily',
#   'need',
#   'slot',
#   'home',
#   'page',
#   'checkout',
#   'show',
#   'slot',
#   'available',
#   'customer',
#   'service',
#   'worst',
#   'speak',
#   'customer',
#   'request',
#   'technical',
#   'issue',
#   'team',
#   'issue',
#   'day',
#   'able',
#   'customer',
#   'request',
#   'need',
#   'shutdown',
#   'business',
#   'already',
#   'app',
#   'able',
#   'use',
#   'future'],
#  ['ever',
#   'fully',
#   'cheating',
#   'product',
#   'time',
#   'delivery',
#   'ever',
#   'credit',
#   'money',
#   'back'],
#  ['option',
#   'poor',
#   'star',
#   'rating',
#   'star',
#   'people',
#   'full',
#   'advantage',
#   'lock',
#   'money',
#   'poor',
#   'quality',
#   'product'],
#  ['fraud', 'legal', 'action', 'money', 'order', 'even', 'refund'],
#  ['pathetic',
#   'service',
#   'order',
#   'sms',
#   'order',
#   'response',
#   'response',
#   'mobile',
#   'delivery',
#   'person',
#   'worst',
#   'last',
#   'buying',
#   'experience'],
#  ['well',
#   'pandemic',
#   'case',
#   'people',
#   'order',
#   'still',
#   'mistake',
#   'right',
#   'delivery',
#   'term',
#   'anyway',
#   'entirely',
#   'hope',
#   'absolutely',
#   'possibly'],
#  ['today',
#   'message',
#   'order',
#   'call',
#   'time',
#   'delivery',
#   'time',
#   'order',
#   'money',
#   'bank_account',
#   'wallet'],
#  ['item', 'issue'],
#  ['egg', 'broken', 'black', 'colour', 'vegetable', 'fresh', 'well'],
#  ['grocery', 'order', 'discussion', 'time', 'delivery', 'slot'],
#  ['request',
#   'order',
#   'continuously',
#   'day',
#   'delivery',
#   'able',
#   'run',
#   'service',
#   'least',
#   'shutdown',
#   'nonsense',
#   'service'],
#  ['subscription',
#   'pkts',
#   'milk',
#   'pkt',
#   'executive',
#   'min',
#   'packet',
#   'min',
#   'executive',
#   'able',
#   'thing',
#   'happend',
#   'today',
#   'packet',
#   'story',
#   'never',
#   'hopeless',
#   'service',
#   'unprofessional',
#   'executive',
#   'online'],
#  ['product',
#   'particularly',
#   'fruit',
#   'fresh',
#   'product',
#   'fresh',
#   'fresh',
#   'fruit',
#   'fresh',
#   'blueberry',
#   'fresh',
#   'well'],
#  ['grocery',
#   'vegetable',
#   'delivery',
#   'slot',
#   'time',
#   'even',
#   'star',
#   'membership',
#   'still',
#   'delivery',
#   'time',
#   'order',
#   'highly',
#   'unprofessional',
#   'behaviour',
#   'item',
#   'stock',
#   'low',
#   'stock',
#   'still',
#   'order',
#   'anymore'],
#  ['product', 'unable', 'deliver', 'product', 'order', 'second', 'time'],
#  ['seriously',
#   'worth',
#   'monthly',
#   'subscription',
#   'daily',
#   'sale',
#   'person',
#   'society',
#   'insufficient',
#   'information',
#   'subscribe'],
#  ['service',
#   'bad',
#   'trust',
#   'worthy',
#   'team',
#   'sometime',
#   'intimate',
#   'much',
#   'wrong',
#   'billing',
#   'need',
#   'attentive',
#   'coordinate',
#   'chat',
#   'refund',
#   'money',
#   'wallet',
#   'quite',
#   'frustrating',
#   'everyday',
#   'surprise',
#   'stock',
#   'item',
#   'delivery',
#   'unfortunately'],
#  ['expensive'],
#  ['shame', 'service', 'poor', 'call', 'centre', 'ppl', 'problem'],
#  ['complete',
#   'item',
#   'cross',
#   'check',
#   'list',
#   'item',
#   'react',
#   'first',
#   'time',
#   'time',
#   'amount',
#   'wallet',
#   'full',
#   'amount',
#   'bad',
#   'quality',
#   'vegitable',
#   'waste',
#   'buying',
#   'customer',
#   'fully',
#   'califlower',
#   'use'],
#  ['absolutely',
#   'unworthy',
#   'service',
#   'co',
#   'ordination',
#   'team',
#   'people',
#   'time',
#   'cheap',
#   'quality',
#   'customer',
#   'service'],
#  ['website', 'reliable', 'first', 'thing', 'trust', 'lack'],
#  ['professional',
#   'cheater',
#   'vegetable',
#   'book',
#   'payment',
#   'always',
#   'mail',
#   'dispatch',
#   'final',
#   'amount',
#   'due',
#   'weight',
#   'change',
#   'mail',
#   'telephonic',
#   'communication',
#   'weighing',
#   'scale',
#   'weight',
#   'confirmation',
#   'customer',
#   'place',
#   'never',
#   'today',
#   'order',
#   'home',
#   'fool',
#   'customer',
#   'actual',
#   'weight',
#   'copy',
#   'final',
#   'product',
#   'sorry',
#   'innconvience',
#   'replace',
#   'product',
#   'refund',
#   'amount',
#   'shortage',
#   'material',
#   'uploading',
#   'snap',
#   'help',
#   'difference',
#   'fraud',
#   'people',
#   'rich'],
#  ['milk',
#   'delivery',
#   'regular',
#   'first',
#   'day',
#   'day',
#   'someday',
#   'even',
#   'office',
#   'drop',
#   'milk',
#   'pocket',
#   'front',
#   'door',
#   'floormat',
#   'back',
#   'pm',
#   'milk',
#   'pocket',
#   'today',
#   'milk',
#   'pocket',
#   'customer',
#   'support',
#   'cs'],
#  ['always',
#   'reason',
#   'extra',
#   'money',
#   'coupon',
#   'automatically',
#   'last',
#   'step',
#   'issue',
#   'time'],
#  ['bad', 'service', 'ever'],
#  ['service', 'bad', 'cheat', 'weight', 'always', 'weight', 'ever'],
#  ['bad',
#   'quality',
#   'vegetable',
#   'almost',
#   'item',
#   'item',
#   'bad',
#   'quality',
#   'able',
#   'fresh',
#   'vegetable',
#   'order',
#   'order',
#   'low',
#   'quality',
#   'vegetable',
#   'vegetable',
#   'rotten',
#   'delivery',
#   'boy',
#   'bad',
#   'back'],
#  ['office',
#   'work',
#   'meantime',
#   'product',
#   'check',
#   'product',
#   'disgust',
#   'trust',
#   'site',
#   'safe',
#   'fraud',
#   'site',
#   'bigbusket',
#   'fraud',
#   'today',
#   'today'],
#  ['clarity',
#   'charge',
#   'free',
#   'wallet',
#   'account',
#   'product',
#   'never',
#   'bill',
#   'different',
#   'ordered',
#   'bill',
#   'list',
#   'cheap',
#   'seller'],
#  ['second',
#   'time',
#   'time',
#   'thing',
#   'available',
#   'thing',
#   'amount',
#   'wallet',
#   'origin',
#   'payment',
#   'debit',
#   'credit_card'],
#  ['pathetic',
#   'service',
#   'mango',
#   'water',
#   'bottle',
#   'package',
#   'package',
#   'image',
#   'instead',
#   'package',
#   'mango',
#   'water',
#   'bottle',
#   'customer',
#   'service',
#   'ready',
#   'customer',
#   'service',
#   'open',
#   'grievance',
#   'customer'],
#  ['fraud'],
#  ['last', 'order', 'customer', 'care', 'order', 'min'],
#  ['fruit',
#   'bad',
#   'quality',
#   'customer',
#   'support',
#   'sale',
#   'people',
#   'bad',
#   'bad',
#   'language',
#   'harish',
#   'executive',
#   'bad',
#   'person',
#   'bad',
#   'behavior',
#   'vegetable',
#   'fruit'],
#  ['time',
#   'mostly',
#   'grocery',
#   'emergency',
#   'purchase',
#   'always',
#   'time',
#   'slot',
#   'delivery',
#   'never',
#   'slot',
#   'afternoon'],
#  ['twice',
#   'order',
#   'representative',
#   'claiming',
#   'payment',
#   'googlepay',
#   'confirmation',
#   'however',
#   'payment',
#   'many',
#   'time',
#   'proof',
#   'bank',
#   'googlepay',
#   'payment',
#   'still',
#   'email',
#   'extra',
#   'transaction',
#   'detail',
#   'payment',
#   'decline',
#   'account',
#   'opposite',
#   'new',
#   'representative',
#   'payment',
#   'useless',
#   'liar',
#   'strongly',
#   'money',
#   'way',
#   'people'],
#  ['pathetic',
#   'service',
#   'mohali',
#   'service',
#   'excellent',
#   'hyderabad',
#   'mohali',
#   'date',
#   'order',
#   'hardly',
#   'issue',
#   'product',
#   'quality',
#   'issue',
#   'product',
#   'wrong',
#   'product',
#   'delivery',
#   'time',
#   'last',
#   'order',
#   'acceptable',
#   'medical',
#   'situation',
#   'family',
#   'reason',
#   'use',
#   'order',
#   'time',
#   'height',
#   'top',
#   'transfer',
#   'money',
#   'wallet',
#   'person',
#   'buy',
#   'middle',
#   'class',
#   'family',
#   'stuff',
#   'already',
#   'money',
#   'stuck',
#   'buy',
#   'market',
#   'pay',
#   'case',
#   'order',
#   'guy',
#   'delayed',
#   'reason',
#   'next',
#   'slot',
#   'day',
#   'order',
#   'dependent',
#   'need',
#   'somewhere',
#   'else',
#   'transfer',
#   'wallet',
#   'use',
#   'amount',
#   'order',
#   'day',
#   'delivery',
#   'slot',
#   'pm'],
#  ['provide',
#   'option',
#   'voucher',
#   'code',
#   'eralier',
#   'transaction',
#   'payment',
#   'online',
#   'cause',
#   'customer',
#   'discount'],
#  ['shopping',
#   'site',
#   'time',
#   'really',
#   'unsatisfied',
#   'customer',
#   'service',
#   'call',
#   'well',
#   'high',
#   'price',
#   'compare',
#   'store',
#   'product',
#   'pm',
#   'pm',
#   'product',
#   'quality',
#   'good',
#   'recommend',
#   'site'],
#  ['item',
#   'multiple',
#   'follow',
#   'up',
#   'clarification',
#   'item',
#   'stock',
#   'never',
#   'issue',
#   'flipkart',
#   'way',
#   'even',
#   'comparable',
#   'other',
#   'worst'],
#  ['expensive',
#   'poor',
#   'quality',
#   'product',
#   'customer',
#   'support',
#   'pathetic'],
#  ['star', 'high', 'poor', 'service'],
#  ['payment',
#   'multiple',
#   'time',
#   'frequent',
#   'follow',
#   'month',
#   'return',
#   'amount',
#   'bank_account',
#   'reply',
#   'different',
#   'customer',
#   'service',
#   'personnel',
#   'amount',
#   'side',
#   'couple',
#   'time',
#   'convince',
#   'fault',
#   'payment'],
#  ['product',
#   'alluring',
#   'offer',
#   'great',
#   'time',
#   'guess',
#   'first',
#   'last',
#   'order'],
#  ['fresh',
#   'cake',
#   'red',
#   'velvet',
#   'cake',
#   'kid',
#   'sick',
#   'later',
#   'request',
#   'return',
#   'instead',
#   'replacement',
#   'cake',
#   'replacement',
#   'need',
#   'replacement',
#   'cake',
#   'cake',
#   'luck',
#   'extremely',
#   'pathetic',
#   'customer',
#   'service'],
#  ['yesterday',
#   'stuff',
#   'today',
#   'message',
#   'stuff',
#   'exact',
#   'weight',
#   'extra',
#   'fair',
#   'example',
#   'order',
#   'extra',
#   'amount',
#   'bad',
#   'thing',
#   'star',
#   'option',
#   'star'],
#  ['file',
#   'complaint',
#   'government',
#   'consumer',
#   'grevience',
#   'helpline',
#   'refund',
#   'bad',
#   'company',
#   'ever',
#   'customer',
#   'service',
#   'rude',
#   'ceo',
#   'still',
#   'bad',
#   'experience',
#   'ever',
#   'company'],
#  ['order',
#   'plate',
#   'early',
#   'oder',
#   'product',
#   'cople',
#   'month',
#   'still',
#   'someidiot',
#   'much',
#   'talkirregular',
#   'word',
#   'nonsense',
#   'number',
#   'chennai',
#   'suggestion',
#   'product',
#   'delivery',
#   'boy',
#   'gentleman',
#   'people',
#   'customer',
#   'action',
#   'immediately',
#   'otherwise',
#   'police'],
#  ['past',
#   'order',
#   'incomplete',
#   'order',
#   'policy',
#   'refund',
#   'amount',
#   'policy',
#   'penalty',
#   'politely',
#   'account',
#   'month',
#   'reminder',
#   'wallet',
#   'card',
#   'regular',
#   'customer',
#   'company',
#   'innocent',
#   'customer'],
#  ['delivery',
#   'charge',
#   'expensive',
#   'product',
#   'seriously',
#   'delivery',
#   'necessary',
#   'mysore',
#   'people',
#   'much',
#   'bad',
#   'people',
#   'profit',
#   'people',
#   'seriously',
#   'plan',
#   'order',
#   'time',
#   'delivery',
#   'charge',
#   'ordering',
#   'early',
#   'delivery',
#   'charge'],
#  ['half',
#   'totally',
#   'contact',
#   'call',
#   'automatically',
#   'even',
#   'cat',
#   'dog',
#   'call',
#   'purchasing',
#   'otherwise',
#   'responsible'],
#  ['delivery',
#   'request',
#   'refund',
#   'product',
#   'account',
#   'info',
#   'end',
#   'cancellation',
#   'delivery',
#   'end'],
#  ['time',
#   'onwards',
#   'last',
#   'order',
#   'bad',
#   'uninstalled',
#   'app',
#   'phone',
#   'delivery',
#   'pm',
#   'pm',
#   'slot',
#   'message',
#   'hat',
#   'slightly',
#   'chat',
#   'message',
#   'order',
#   'pm',
#   'pm',
#   'slot',
#   'even',
#   'time',
#   'order',
#   'half',
#   'item',
#   'prepaid',
#   'order'],
#  ['bunch',
#   'crook',
#   'new',
#   'way',
#   'people',
#   'group',
#   'market',
#   'world',
#   'people',
#   'inform',
#   'group',
#   'deliver',
#   'order',
#   'whim',
#   'fancy'],
#  ['terrible',
#   'experience',
#   'availabilty',
#   'area',
#   'lot',
#   'time',
#   'long',
#   'app',
#   'item',
#   'stock',
#   'suddenly',
#   'poor'],
#  ['real',
#   'unprofessional',
#   'even',
#   'check',
#   'expiry_date',
#   'product',
#   'organic',
#   'product',
#   'old',
#   'stock',
#   'warm',
#   'pulse',
#   'online',
#   'advance',
#   'refunding',
#   'amount',
#   'amount',
#   'wallet',
#   'place',
#   'order',
#   'charge',
#   'delivery',
#   'fee',
#   'really',
#   'lately',
#   'standard',
#   'customer',
#   'care',
#   'total',
#   'waste',
#   'time',
#   'money',
#   'totally'],
#  ['bad', 'experience', 'product', 'request', 'time', 'slot', 'pick', 'pick'],
#  ['order',
#   'atleast',
#   'product',
#   'stale',
#   'edible',
#   'accept',
#   'return',
#   'thing',
#   'finally',
#   'credit',
#   'amount',
#   'wallet',
#   'place',
#   'order',
#   'charge',
#   'delivery',
#   'fee',
#   'mean',
#   'team',
#   'product',
#   'useless',
#   'even',
#   'check',
#   'packing',
#   'delivery',
#   'guy',
#   'unhygienic',
#   'standard',
#   'low',
#   'hire',
#   'star',
#   'grievance',
#   'mind',
#   'doubt',
#   'review',
#   'complaint',
#   'time',
#   'total',
#   'disappointment',
#   'transaction'],
#  ['item',
#   'nuttie',
#   'chocolate',
#   'baskin',
#   'cream',
#   'pm',
#   'pm',
#   'message',
#   'hour',
#   'delivery',
#   'item',
#   'available',
#   'delivery',
#   'show',
#   'message',
#   'placing',
#   'order',
#   'customer',
#   'sale',
#   'available',
#   'possible',
#   'product',
#   'available',
#   'particular',
#   'customer'],
#  ['aka',
#   'muthurama',
#   'steal',
#   'product',
#   'item',
#   'blue',
#   'bike',
#   'people',
#   'steal',
#   'daily',
#   'brother',
#   'already',
#   'police',
#   'case',
#   'misbehavior',
#   'harassment',
#   'sunder',
#   'corrupt',
#   'boy',
#   'chennai',
#   'working',
#   'shame',
#   'people'],
#  ['really',
#   'pathetic',
#   'horrible',
#   'experience',
#   'subscription',
#   'packet',
#   'milk',
#   'sometimes',
#   'none',
#   'kind',
#   'thing',
#   'strict',
#   'guideline',
#   'delivery',
#   'kind',
#   'thing',
#   'afternoon',
#   'silently',
#   'money',
#   'else',
#   'money',
#   'ridiculous',
#   'check',
#   'time',
#   'delivery',
#   'person',
#   'thing',
#   'milk',
#   'packet',
#   'really',
#   'pathetic',
#   'quality',
#   'service',
#   'definitely',
#   'bad',
#   'experience'],
#  ['delete'],
#  ['service',
#   'past',
#   'day',
#   'product',
#   'time',
#   'customer',
#   'service',
#   'team',
#   'issue',
#   'order',
#   'money',
#   'partly',
#   'full',
#   'provision',
#   'directly',
#   'customer',
#   'service',
#   'person',
#   'discount',
#   'order',
#   'beggar',
#   'third',
#   'rate',
#   'service',
#   'face',
#   'terribly',
#   'disappointed',
#   'future'],
#  ['pathetic',
#   'service',
#   'order',
#   'morning',
#   'slot',
#   'full',
#   'order',
#   'confirmation',
#   'evening',
#   'convenient',
#   'slot',
#   'next',
#   'finally',
#   'half',
#   'item',
#   'reason',
#   'need',
#   'follow',
#   'complete',
#   'delivery',
#   'really',
#   'bad',
#   'customer',
#   'friendly',
#   'never'],
#  ['service',
#   'app',
#   'day',
#   'day',
#   'issue',
#   'error',
#   'paste',
#   'statement',
#   'apology',
#   'money',
#   'refund',
#   'money',
#   'solution',
#   'service',
#   'industry'],
#  ['daily',
#   'rd',
#   'grade',
#   'service',
#   'big',
#   'brand',
#   'brand',
#   'never',
#   'daily',
#   'product',
#   'milk',
#   'egg',
#   'consecutively',
#   'day',
#   'daily',
#   'blunder',
#   'bbdaily',
#   'incapable',
#   'customer',
#   'service',
#   'bbdaily',
#   'pathetic',
#   'template',
#   'reply',
#   'query',
#   'bbdaily',
#   'new',
#   'bbdaily',
#   'review',
#   'customer',
#   'name',
#   'minu',
#   'genuine',
#   'review',
#   'public',
#   'portal',
#   'personal',
#   'info'],
#  ['bad', 'service', 'delivery', 'person', 'manner', 'customer', 'service'],
#  ['bad', 'firstorder'],
#  ['bad'],
#  ['delivery',
#   'horrible',
#   'never',
#   'time',
#   'occasion',
#   'incomplete',
#   'address',
#   'reason',
#   'failure',
#   'delivery',
#   'fruit',
#   'vegetable',
#   'sometimes',
#   'rotten',
#   'condition'],
#  ['dear',
#   'customer',
#   'product',
#   'bad',
#   'quality',
#   'product',
#   'vegetable',
#   'product'],
#  ['order',
#   'product',
#   'due',
#   'item',
#   'first',
#   'order',
#   'minute',
#   'cancellation',
#   'fee',
#   'rs',
#   'item',
#   'delivery',
#   'slot',
#   'pm',
#   'deliver',
#   'cashback',
#   'delivery',
#   'time',
#   'past',
#   'call',
#   'team',
#   'issue',
#   'call',
#   'minute',
#   'resolve',
#   'issue',
#   'call',
#   'consent',
#   'order',
#   'instead',
#   'money',
#   'source',
#   'wallet',
#   'account',
#   'pathetic',
#   'delivery',
#   'service',
#   'surely',
#   'action'],
#  ['loyal',
#   'customer',
#   'today',
#   'third',
#   'time',
#   'product',
#   'totally',
#   'acceptable',
#   'distribution',
#   'office',
#   'number',
#   'response'],
#  ['force', 'customer', 'minimum', 'billing', 'approach', 'sell', 'customer'],
#  ['bad',
#   'experience',
#   'great',
#   'disappointment',
#   'guy',
#   'liar',
#   'respect',
#   'real',
#   'cheap',
#   'bad',
#   'shopping',
#   'site',
#   'ever',
#   'around'],
#  ['order',
#   'thing',
#   'place',
#   'always',
#   'delivery',
#   'slot',
#   'full',
#   'mean',
#   'telling',
#   'thing',
#   'place',
#   'actually',
#   'crucial',
#   'time',
#   'really'],
#  ['order',
#   'intimation',
#   'refund',
#   'even',
#   'response',
#   'many',
#   'mail',
#   'money',
#   'day',
#   'message',
#   'status'],
#  ['bad',
#   'bad',
#   'people',
#   'able',
#   'unable',
#   'book',
#   'slot',
#   'slot',
#   'money',
#   'wallet',
#   'able',
#   'amount',
#   'refund',
#   'even',
#   'slot',
#   'even',
#   'query'],
#  ['grocery',
#   'veggie',
#   'rd',
#   'delivery',
#   'date',
#   'due',
#   'non',
# ...
#   'collect'],
#  ['week', 'time', 'product', 'even', 'delivery', 'charge', 'worth'],
#  ['waste', 'time', 'money', 'effort', 'energy'],
#  ['highly', 'responce'],
#  ['time',
#   'never',
#   'product',
#   'time',
#   'slot',
#   'always',
#   'late',
#   'even',
#   'bit',
#   'suddenly',
#   'pathetic',
#   'way',
#   'delivery',
#   'point',
#   'business'],
#  ['suddenly',
#   'membership',
#   'card',
#   'permission',
#   'wallet',
#   'negative',
#   'balance',
#   'activated',
#   'membership',
#   'totally',
#   'fraud',
#   'permission'],
#  ['personnel', 'delivery', 'bluntly', 'nonchalantly'],
#  ['stuff',
#   'vegetable',
#   'stale',
#   'picture',
#   'amusing',
#   'ridiculous',
#   'imagine',
#   'service',
#   'level',
#   'pathetic'],
#  ['even', 'supervisor', 'person', 'contact', 'delivery'],
#  ['report', 'issue', 'app', 'entry'],
#  ['even', 'customer'],
#  ['due', 'time', 'item', 'item', 'present', 'app', 'list'],
#  ['strange', 'practice', 'indeed'],
#  ['shocking',
#   'part',
#   'item',
#   'stock',
#   'app',
#   'time',
#   'heart',
#   'item',
#   'cancellation',
#   'notification'],
#  ['customer', 'service', 'pathetic'],
#  ['even', 'option', 'coupon', 'work', 'namesake', 'fool', 'customer'],
#  ['payment',
#   'page',
#   'time',
#   'page',
#   'almost',
#   'hour',
#   'still',
#   'end',
#   'hour',
#   'min',
#   'error',
#   'page'],
#  ['first',
#   'pandemic',
#   'situation',
#   'people',
#   'job',
#   'money',
#   'time',
#   'value',
#   'second',
#   'lockdown',
#   'money',
#   'grocery',
#   'money'],
#  ['future',
#   'never',
#   'ever',
#   'online',
#   'shopping',
#   'website',
#   'even',
#   'free',
#   'product',
#   'service',
#   'much',
#   'upset',
#   'service',
#   'cry'],
#  ['last',
#   'order',
#   'item',
#   'later',
#   'material',
#   'oil',
#   'oil',
#   'sachet',
#   'complaint',
#   'customer',
#   'care',
#   'solution'],
#  ['unfair', 'pay', 'negligence'],
#  ['never', 'company', 'poor', 'service', 'care', 'customer'],
#  ['suggestion',
#   'payment',
#   'try',
#   'app',
#   'mean',
#   'end',
#   'eventually',
#   'software',
#   'issue'],
#  ['inactivated', 'account', 'theft', 'wallet', 'amount'],
#  ['salt', 'injury', 'grievance'],
#  ['suggestable',
#   'shutdown',
#   'service',
#   'customer',
#   'panic',
#   'rotten',
#   'nasty',
#   'service',
#   'theft',
#   'customer',
#   'wallet'],
#  ['star', 'poor', 'quality', 'star'],
#  ['raise', 'issue', 'food', 'grocery'],
#  ['issue',
#   'low',
#   'efficiency',
#   'order',
#   'single',
#   'latency',
#   'payment',
#   'handling'],
#  ['fake', 'offer'],
#  ['online',
#   'grocery',
#   'provider',
#   'digital',
#   'gateway',
#   'bad',
#   'amount',
#   'bank_account',
#   'gateway',
#   'customer',
#   'face',
#   'harassment',
#   'money',
#   'back',
#   'strongly',
#   'deal'],
#  ['especially',
#   'bank',
#   'transaction',
#   'payment',
#   'responsibility',
#   'instead',
#   'customer',
#   'twice'],
#  ['utter', 'nonsense'],
#  ['totally',
#   'unprofessional',
#   'accept',
#   'truth',
#   'lie',
#   'phone',
#   'phone',
#   'automatically',
#   'many',
#   'store',
#   'nearby',
#   'time',
#   'online',
#   'service',
#   'unhappy',
#   'customer'],
#  ['quality', 'manager'],
#  ['compulsive',
#   'abuser',
#   'thick',
#   'skin',
#   'even',
#   'time',
#   'day',
#   'wrong',
#   'payment'],
#  ['water', 'die', 'year', 'old'],
#  ['water', 'responsible'],
#  ['wrong', 'end'],
#  [],
#  ['finally',
#   'write',
#   'school',
#   'kid',
#   'empty',
#   'space',
#   'page',
#   'even',
#   'empty',
#   'answer',
#   'sheet',
#   'several',
#   'interview',
#   'life',
#   'never',
#   'bad',
#   'scam',
#   'person',
#   'type',
#   'email',
#   'social',
#   'medium',
#   'computer',
#   'moron',
#   'hr',
#   'team',
#   'people',
#   'write',
#   'reply',
#   'review',
#   'customer',
#   'instead',
#   'test',
#   'computer',
#   'hrs',
#   'write',
#   'reply',
#   'clear',
#   'applicant'],
#  ['people',
#   'clear',
#   'unbelievable',
#   'whole',
#   'thing',
#   'hrs',
#   'candidate',
#   'rewrite',
#   'even',
#   'lunch',
#   'break',
#   'already',
#   'past',
#   'pm',
#   'dumb',
#   'hr',
#   'arvind',
#   'test',
#   'hardly',
#   'min',
#   'never',
#   'back',
#   'call',
#   'check',
#   'moron',
#   'arvind',
#   'test',
#   'year',
#   'international',
#   'voice',
#   'experience',
#   'quality',
#   'control',
#   'team',
#   'leader',
#   'trainer',
#   'many',
#   'corporate',
#   'bad',
#   'owner',
#   'management',
#   'hard',
#   'money',
#   'business',
#   'vanish',
#   'market',
#   'huge',
#   'loss',
#   'irresponsible',
#   'staff',
#   'member'],
#  ['people', 'ready', 'job', 'begger', 'image'],
#  ['false', 'commitment', 'simple', 'problem', 'least', 'followup'],
#  ['meantime',
#   'attempt',
#   'stack',
#   'thing',
#   'customer',
#   'call',
#   'rude',
#   'behavior',
#   'junkie',
#   'mental',
#   'tension',
#   'prevalent',
#   'email',
#   'attempt',
#   'ip',
#   'address',
#   'attempt',
#   'attempt',
#   'source',
#   'bank_account',
#   'transaction',
#   'transaction'],
#  ['purpose',
#   'tap',
#   'email',
#   'address',
#   'call',
#   'log',
#   'purpose',
#   'steal',
#   'identity'],
#  ['overall',
#   'culprit',
#   'fraud',
#   'business',
#   'customer',
#   'unnoticed',
#   'time',
#   'return',
#   'never',
#   'completely'],
#  ['compensation', 'money', 'back', 'order', 'take', 'wallet', 'day', 'stupid'],
#  ['covid',
#   'risk',
#   'situation',
#   'item',
#   'bag',
#   'handover',
#   'item',
#   'individually',
#   'delivery',
#   'person',
#   'touch',
#   'item',
#   'handover'],
#  ['bad',
#   'company',
#   'adapt',
#   'procedure',
#   'public',
#   'safety',
#   'understand',
#   'use',
#   'plastic',
#   'case',
#   'pack',
#   'item',
#   'paper',
#   'bag',
#   'handover',
#   'people',
#   'risk'],
#  ['precaution', 'need', 'high', 'authority'],
#  ['app', 'placing', 'order', 'order'],
#  ['vegetable', 'poor', 'quality', 'whole', 'world'],
#  ['delivery', 'sure'],
#  ['pathetic', 'support', 'chat', 'option'],
#  ['day',
#   'exactly',
#   'thing',
#   'delivery',
#   'item',
#   'time',
#   'support',
#   'guy',
#   'money',
#   'bank_account',
#   'immediately',
#   'working',
#   'day',
#   'place'],
#  ['item', 'garbage', 'bad', 'rotten'],
#  ['type', 'bad'],
#  ['apple', 'pc', 'apple', 'bad'],
#  [],
#  ['poor', 'quality', 'extremely', 'raw'],
#  ['onion', 'entire', 'package', 'bad'],
#  ['pathetic', 'service'],
#  ['membership', 'priority', 'delivery', 'idiot', 'waste', 'money'],
#  ['iem'],
#  ['app',
#   'last',
#   'personal',
#   'debit_card',
#   'information',
#   'app',
#   'permission',
#   'frequent',
#   'card',
#   'serious',
#   'issue',
#   'personal',
#   'information',
#   'financial',
#   'loss'],
#  ['issue',
#   'app',
#   'portal',
#   'credit',
#   'information',
#   'app',
#   'illegally',
#   'staff',
#   'hacker',
#   'fraudulent',
#   'transaction'],
#  ['least',
#   'last',
#   'order',
#   'vegetable',
#   'next_day',
#   'purchase',
#   'early',
#   'bad',
#   'giving',
#   'chill',
#   'veggie',
#   'health',
#   'trash',
#   'purchasing',
#   'vegetable'],
#  ['uneasy', 'feeling', 'last', 'day', 'vegetable', 'post', 'today'],
#  ['order', 'late', 'evening'],
#  ['carrot', 'stinking', 'fungus'],
#  ['pudina', 'leafs', 'black', 'green', 'next', 'day'],
#  ['dnstair',
#   'away',
#   'updtd',
#   'order',
#   'complete',
#   'sorry',
#   'dn',
#   'fraud',
#   'customer',
#   'money',
#   'good',
#   'order',
#   'status',
#   'complete'],
#  ['many',
#   'day',
#   'order',
#   'even',
#   'last',
#   'time',
#   'full',
#   'order',
#   'irrational',
#   'delivery',
#   'time',
#   'faulty',
#   'delivery',
#   'mechanism'],
#  ['order', 'payment'],
#  ['mob'],
#  ['call', 'bangalore', 'office', 'day', 'back', 'torture', 'customer'],
#  ['customer',
#   'support',
#   'team',
#   'standard',
#   'word',
#   'apology',
#   'escalation',
#   'operation',
#   'team',
#   'solution'],
#  ['careful', 'cautious', 'manipulate', 'thing'],
#  ['lockdown',
#   'new',
#   'company',
#   'old',
#   'favorite',
#   'long',
#   'helpful',
#   'company',
#   'com'],
#  ['delivery',
#   'timeliness',
#   'lockdown',
#   'last',
#   'week',
#   'never',
#   'single',
#   'slot',
#   'available',
#   'delivery',
#   'brother',
#   'essential',
#   'instead',
#   'order',
#   'text',
#   'last_minute',
#   'customer',
#   'service',
#   'order'],
#  ['time'],
#  ['unreliable'],
#  ['unprofessional'],
#  ['complete', 'waste', 'time', 'money'],
#  ['company', 'company', 'company', 'company', 'company', 'company'],
#  ['guy', 'lockdown'],
#  ['even', 'delivery', 'time'],
#  ['inconvenience',
#   'time',
#   'home',
#   'text',
#   'home',
#   'customer',
#   'service',
#   'date',
#   'day',
#   'delivery',
#   'day',
#   'refunded'],
#  ['short',
#   'stock',
#   'upload',
#   'thing',
#   'site',
#   'half',
#   'hour',
#   'item',
#   'cart',
#   'message',
#   'front',
#   'item',
#   'unavailable',
#   'particular',
#   'time',
#   'bot',
#   'present',
#   'order',
#   'day',
#   'delivery',
#   'boy',
#   'grocery',
#   'order',
#   'unproffesional'],
#  ['use',
#   'app',
#   'careless',
#   'people',
#   'app',
#   'unproffesional',
#   'careless',
#   'sometimes',
#   'fruit',
#   'bad'],
#  ['app', 'choice', 'pathetic', 'situationn'],
#  ['understandable',
#   'delivery',
#   'delay',
#   'stock',
#   'customer',
#   'operational',
#   'inefficiency',
#   'totally',
#   'unacceptable'],
#  ['firstly',
#   'hour',
#   'website',
#   'item',
#   'cart',
#   'checkout',
#   'slot',
#   'available',
#   'later',
#   'frustrating',
#   'customer',
#   'waste',
#   'time',
#   'place',
#   'order',
#   'time',
#   'item',
#   'already',
#   'cart',
#   'unavailable',
#   'whole',
#   'experience',
#   'frustrating'],
#  ['morning',
#   'email',
#   'delivery',
#   'person',
#   'doorstep',
#   'mobile',
#   'delivery',
#   'order',
#   'bbo',
#   'response',
#   'end',
#   'order',
#   'intimation',
#   'refund',
#   'delivery'],
#  ['however',
#   'right',
#   'home',
#   'doorstep',
#   'even',
#   'cctv',
#   'footage',
#   'delivery',
#   'boy',
#   'premise',
#   'inefficiency',
#   'deliver'],
#  ['frustrated',
#   'back',
#   'time',
#   'email',
#   'absolutely',
#   'response',
#   'customer',
#   'service',
#   'pathetic',
#   'lazy',
#   'frustrating',
#   'unprofessional',
#   'word',
#   'mind',
#   'customer',
#   'service'],
#  ['follow',
#   'mad',
#   'person',
#   'phone',
#   'support',
#   'good',
#   'first',
#   'time',
#   'response',
#   'team',
#   'couple',
#   'time',
#   'previous',
#   'order',
#   'bad',
#   'quality',
#   'watermelon',
#   'item',
#   'response',
#   'instead',
#   'item',
#   'wallet',
#   'infuriate'],
#  ['earnest',
#   'hard',
#   'money',
#   'cheater',
#   'customer',
#   'service',
#   'completely',
#   'unprofessional'],
#  ['fool'],
#  ['time', 'customer'],
#  ['customer', 'care', 'even', 'money', 'back'],
#  ['people', 'people', 'option', 'government', 'organisation', 'seriously'],
#  ['cheap', 'tactic', 'time'],
#  ['even', 'problem'],
#  [],
#  ['order', 'money'],
#  ['cheater'],
#  ['day',
#   'order',
#   'refunded',
#   'amount',
#   'item',
#   'refund',
#   'delivery',
#   'charge',
#   'delivery',
#   'charge'],
#  [],
#  ['total', 'stupid', 'day'],
#  ['emotion',
#   'team',
#   'member',
#   'owner',
#   'company',
#   'hell',
#   'fraud',
#   'time',
#   'situation',
#   'people',
#   'different',
#   'place',
#   'option',
#   'thing',
#   'necessary',
#   'food',
#   'item',
#   'family'],
#  ['even',
#   'odd',
#   'hour',
#   'midnight',
#   'type',
#   'hourly',
#   'window',
#   'regularly',
#   'day'],
#  ['post',
#   'payment',
#   'operational',
#   'issue',
#   'money',
#   'yet',
#   'critical',
#   'time',
#   'money',
#   'main',
#   'thing'],
#  ['first',
#   'order',
#   'last',
#   'key',
#   'food',
#   'item',
#   'stock',
#   'home',
#   'delivery',
#   'saturday',
#   'delay',
#   'due',
#   'lockdown',
#   'slot',
#   'pm',
#   'choice',
#   'ok',
#   'slot',
#   'dismay',
#   'delivery',
#   'boy',
#   'call',
#   'center',
#   'order',
#   'due',
#   'lack',
#   'staff',
#   'case',
#   'order',
#   'first',
#   'place',
#   'really',
#   'day',
#   'wait',
#   'day'],
#  ['customer',
#   'year',
#   'extremely',
#   'dissatisfied',
#   'carefree',
#   'attitude',
#   'call',
#   'center',
#   'agent',
#   'order',
#   'update',
#   'customer',
#   'complaint',
#   'review',
#   'least',
#   'situation',
#   'well',
#   'false',
#   'assurance',
#   'customer'],
#  ['veggie', 'instead', 'long'],
#  ['disappointed',
#   'way',
#   'due',
#   'current',
#   'situation',
#   'thing',
#   'difficult',
#   'promise',
#   'secondly',
#   'money',
#   'back',
#   'credit_card',
#   'credit',
#   'money',
#   'wallet'],
#  ['poor', 'service'],
#  ['first',
#   'app',
#   'due',
#   'excess',
#   'order',
#   'slot',
#   'time',
#   'order',
#   'automatically',
#   'even',
#   'requirement',
#   'reorder',
#   'next',
#   'slot',
#   'closed',
#   'slot'],
#  ['less', 'critical', 'situation'],
#  ['money', 'people', 'situation', 'opportunity', 'clearly', 'service'],
#  ['customer', 'care', 'always', 'parroted', 'excuse', 'operational', 'issue'],
#  ['free', 'milk', 'offer', 'sale', 'person'],
#  ['bbd'],
#  ['totally', 'disappointed', 'service'],
#  ['time',
#   'reschedule',
#   'delivery',
#   'time',
#   'convenience',
#   'end',
#   'customer',
#   'service',
#   'schedule',
#   'time',
#   'team',
#   'assure'],
#  ['quite', 'disappointing', 'horrible', 'experience'],
#  ['bad', 'service'],
#  ['order',
#   'number',
#   'morning',
#   'evening',
#   'th',
#   'automatically',
#   'twice',
#   'still',
#   'yet'],
#  ['good', 'brand', 'image'],
#  ['milk',
#   'boy',
#   'milk',
#   'salary',
#   'regularly',
#   'boy',
#   'work',
#   'milk',
#   'neighboring',
#   'community',
#   'team',
#   'milk',
#   'sir',
#   'sad',
#   'company',
#   'hefty',
#   'fee',
#   'celebrity',
#   'salary',
#   'delivery',
#   'boy'],
#  ['finally',
#   'bbdaily',
#   'app',
#   'phone',
#   'scamster',
#   'company',
#   'order',
#   'cheat',
#   'weight',
#   'product'],
#  ['company',
#   'crore',
#   'income',
#   'plastic',
#   'food',
#   'big',
#   'shame',
#   'advertising',
#   'pathetic',
#   'company'],
#  ['intention',
#   'need',
#   'order',
#   'secondly',
#   'thing',
#   'free',
#   'payment',
#   'free',
#   'thing',
#   'available',
#   'free',
#   'show',
#   'thing',
#   'free',
#   'item'],
#  ['second', 'time', 'vegetable', 'time'],
#  ['bad',
#   'experience',
#   'com',
#   'online',
#   'grocery',
#   'customer',
#   'harrowing',
#   'experience',
#   'order',
#   'last',
#   'moment'],
#  ['thank',
#   'service',
#   'last',
#   'month',
#   'forward',
#   'never',
#   'mohali',
#   'trust',
#   'mohali'],
#  ['amaranthus',
#   'last',
#   'time',
#   'even',
#   'sand',
#   'properly',
#   'claim',
#   'carrot',
#   'bean',
#   'day',
#   'fresh',
#   'flower',
#   'mostly'],
#  ['dry', 'quality', 'product'],
#  ['address',
#   'regular',
#   'customer',
#   'grofer',
#   'com',
#   'occasionally',
#   'bad',
#   'experience',
#   'time',
#   'hence',
#   'write',
#   'com'],
#  ['point',
#   'address',
#   'already',
#   'address',
#   'early',
#   'mobile',
#   'number',
#   'warehouse',
#   'team',
#   'lie'],
#  ['previously', 'zorabian', 'chicken', 'brand', 'heavily', 'disappointing'],
#  ['packaging',
#   'poor',
#   'contamination',
#   'meat',
#   'properly',
#   'zorabian',
#   'chicken'],
#  ['likewise', 'bread', 'often', 'expire', 'day', 'pack'],
#  ['bunch', 'crook'],
#  ['even', 'stock', 'sale', 'money', 'credit', 'horrible', 'experience'],
#  ['totally'],
#  ['bbdaily', 'intiative', 'brand'],
#  ['chat',
#   'cancelation',
#   'money',
#   'transfer',
#   'wallet',
#   'unsable',
#   'policy',
#   'user'],
#  ['many', 'poor', 'quality', 'item'],
#  ['option', 'slot', 'thing', 'stock'],
#  ['order',
#   'thing',
#   'fun',
#   'order',
#   'business',
#   'model',
#   'need',
#   'need',
#   'tell',
#   'customer',
#   'right',
#   'away'],
#  ['sure',
#   'thing',
#   'second',
#   'customer',
#   'plain',
#   'team',
#   'customer',
#   'order',
#   'reason'],
#  ['customer',
#   'support',
#   'team',
#   'customer',
#   'suffering',
#   'order',
#   'last',
#   'moment',
#   'team',
#   'due',
#   'reason',
#   'next',
#   'available',
#   'slot'],
#  ['order',
#   'third',
#   'class',
#   'company',
#   'fool',
#   'dirty',
#   'product',
#   'bigbasket'],
#  ['social', 'medium', 'team', 'useless', 'fit', 'job'],
#  ['guy', 'still', 'use', 'product', 'risk', 'health'],
#  ['voice', 'company'],
#  ['people',
#   'use',
#   'payment',
#   'mode',
#   'credit',
#   'profit',
#   'scheme',
#   'cod',
#   'bad',
#   'product'],
#  ['customer', 'service', 'pathetic', 'response', 'even', 'item', 'refund'],
#  ['people', 'item', 'bi'],
#  ['secondly',
#   'price',
#   'portal',
#   'fraudulent',
#   'login',
#   'detail',
#   'totally',
#   'different',
#   'high',
#   'offer',
#   'coupon'],
#  [],
#  ['delivery', 'info'],
#  ['recent', 'unpleasant', 'experience'],
#  ['month',
#   'product',
#   'issue',
#   'initially',
#   'later',
#   'consumer',
#   'feel',
#   'item',
#   'false',
#   'promotion',
#   'never',
#   'backend',
#   'escalation',
#   'team',
#   'quite',
#   'customer',
#   'issue'],
#  ['recent', 'one', 'cart', 'cart', 'empty'],
#  ['customer', 'service', 'unable', 'resolve', 'problem', 'request'],
#  ['point', 'silly', 'breakthrough', 'idea'],
#  ['rotten',
#   'product',
#   'wrong',
#   'product',
#   'many',
#   'time',
#   'time',
#   'couple',
#   'product',
#   'cash',
#   'item',
#   'multiple',
#   'time',
#   'inefficient',
#   'executive',
#   'false',
#   'commitment',
#   'well',
#   'use'],
#  ['simply', 'organic', 'fresh', 'vegetable', 'true', 'instance', 'many'],
#  ['trust', 'customer'],
#  ['agitated', 'spending', 'evening'],
#  ...]

# %%
import gensim.corpora as corpora
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)
# Create Corpus
texts = data_lemmatized
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)]]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics= 13,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=1000,
                                           per_word_topics=True)

# %%
#I removed the comments to make the bloc shorter
def format_topics_sentences(corpus, texts, ldamodel=None):
    data = []

    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list
        row = sorted(row, key=lambda x: x[1], reverse=True)

        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                data.append([int(topic_num), round(prop_topic, 4), topic_keywords])
            else:
                break

    sent_topics_df = (
        pd.DataFrame(data, columns=[
            'Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords'])
                .assign(Text= texts) # or use Text= pd.Series(text)
    )

    return sent_topics_df

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_lemmatized)
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(13)
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0             0               2              0.3751
# 1             1               2              0.3203
# 2             2              10              0.6513
# 3             3               4              0.3173
# 4             4               3              0.8578
# 5             5              11              0.3077
# 6             6               2              0.9423
# 7             7               3              0.8462
# 8             8               3              0.5328
# 9             9               8              0.5165
# 10           10               2              0.5619
# 11           11               2              0.8462
# 12           12               3              0.9341
#
#                                              Keywords  \
# 0   item, time, product, problem, delivery, really...
# 1   item, time, product, problem, delivery, really...
# 2   good, bad, fruit, com, never, quality, people,...
# 3   issue, instead, veggie, replacement, cancellat...
# 4   service, customer, order, time, bad, even, day...
# 5   account, review, mobile, health, card, rude, c...
# 6   item, time, product, problem, delivery, really...
# 7   service, customer, order, time, bad, even, day...
# 8   service, customer, order, time, bad, even, day...
# 9   website, price, thing, shopping, second, groce...
# 10  item, time, product, problem, delivery, really...
# 11  item, time, product, problem, delivery, really...
# 12  service, customer, order, time, bad, even, day...
#
#                                                  Text
# 0                 [product, still, yet, last, amount]
# 1   [product, item, request, refund, back, time, r...
# 2   [bad, quality, product, specially, fruit, bad,...
# 3   [thing, delivery, sort, problem, instead, milk...
# 4   [regular, user, major, issue, payment, payment...
# 5   [bad, pathetic, experience, executive, soft, s...
# 6   [unnecessarily, amount, delivery, charge, char...
# 7    [pathetic, service, pathetic, customer, support]
# 8   [delivery, slot, fancy, message, delivery, cus...
# 9   [delivery, man, raju, deliver, food, door, fro...
# 10   [bad, app, milk, time, check, site, fraud, site]
# 11  [extra, charge, customer, bad, management, bad...
# 12  [useless, app, place, order, time, even, even,...

# %%
# Display setting to show more characters in column
pd.options.display.max_colwidth = 90

sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet,
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)],
                                            axis=0)

# Reset Index
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(20)

sent_topics_sorteddf_mallet.to_csv("Negative 13_25_April_24.csv")

# %%
from gensim.matutils import hellinger
from scipy import spatial as scs
from scipy.cluster import hierarchy as sch
from scipy.spatial.distance import pdist, squareform


# get topic distributions
topic_dist = lda_model.state.get_lambda()

# get topic terms
num_words = 15
topic_terms = [{w for (w, _) in lda_model.show_topic(topic, topn=num_words)} for topic in range(topic_dist.shape[0])]

# no. of terms to display in annotation
n_ann_terms = 15

# use hellinger distance metric in dendrogram
def js_dist(X):
    return pdist(X, lambda u, v: hellinger(u, v))

# define method for distance calculation in clusters
linkagefun=lambda x: sch.linkage(x, 'single')

# calculate text annotations
def text_annotation(topic_dist, topic_terms, n_ann_terms, linkagefun):
    # get dendrogram hierarchy data
    linkagefun = lambda x: sch.linkage(x, 'single')
    d = js_dist(topic_dist)
    Z = linkagefun(d)
    P = sch.dendrogram(Z, orientation="bottom", no_plot=True)

    # store topic no.(leaves) corresponding to the x-ticks in dendrogram
    x_ticks = np.arange(5, len(P['leaves']) * 10 + 5, 10)
    x_topic = dict(zip(P['leaves'], x_ticks))

    # store {topic no.:topic terms}
    topic_vals = dict()
    for key, val in x_topic.items():
        topic_vals[val] = (topic_terms[key], topic_terms[key])

    text_annotations = []
    # loop through every trace (scatter plot) in dendrogram
    for trace in P['icoord']:
        fst_topic = topic_vals[trace[0]]
        scnd_topic = topic_vals[trace[2]]

        # annotation for two ends of current trace
        pos_tokens_t1 = list(fst_topic[0])[:min(len(fst_topic[0]), n_ann_terms)]
        neg_tokens_t1 = list(fst_topic[1])[:min(len(fst_topic[1]), n_ann_terms)]

        pos_tokens_t4 = list(scnd_topic[0])[:min(len(scnd_topic[0]), n_ann_terms)]
        neg_tokens_t4 = list(scnd_topic[1])[:min(len(scnd_topic[1]), n_ann_terms)]

        t1 = "<br>".join((": ".join(("+++", str(pos_tokens_t1))), ": ".join(("---", str(neg_tokens_t1)))))
        t2 = t3 = ()
        t4 = "<br>".join((": ".join(("+++", str(pos_tokens_t4))), ": ".join(("---", str(neg_tokens_t4)))))

        # show topic terms in leaves
        if trace[0] in x_ticks:
            t1 = str(list(topic_vals[trace[0]][0])[:n_ann_terms])
        if trace[2] in x_ticks:
            t4 = str(list(topic_vals[trace[2]][0])[:n_ann_terms])

        text_annotations.append([t1, t2, t3, t4])

        # calculate intersecting/diff for upper level
        intersecting = fst_topic[0] & scnd_topic[0]
        different = fst_topic[0].symmetric_difference(scnd_topic[0])

        center = (trace[0] + trace[2]) / 2
        topic_vals[center] = (intersecting, different)

        # remove trace value after it is annotated
        topic_vals.pop(trace[0], None)
        topic_vals.pop(trace[2], None)

    return text_annotations

# %%
import plotly.figure_factory as ff
import plotly.offline as py
# get text annotations
annotation = text_annotation(topic_dist, topic_terms, n_ann_terms, linkagefun)

# Plot dendrogram
names = ['Topic 1', 'Topic 2', 'Topic 3', 'Topic 4', 'Topic 5','Topic 6','Topic 7','Topic 8','Topic 9','Topic 10','Topic 11', 'Topic 12','Topic 13']
dendro = ff.create_dendrogram(topic_dist, distfun=js_dist, linkagefun=linkagefun, hovertext=annotation, orientation="right", labels=names)
dendro['layout'].update({'width': 1200, 'height': 600})
py.iplot(dendro)
file='/content/images/Dendrogram_Neg.png'
dendro.write_image(file)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1be7ee3a-91c9-4fba-8bbe-28b693ac8007" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1be7ee3a-91c9-4fba-8bbe-28b693ac8007")) {                    Plotly.newPlot(                        "1be7ee3a-91c9-4fba-8bbe-28b693ac8007",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["['shipment', 'plastic', 'conveyance', 'trick', 'odered', 'utm', 'truly', 'fresho', 'record', 'jug', 'result', 'main', 'terrible', 'yet', 'however']","()","()","['image', 'lot', 'critical', 'though', 'pc', 'cooking', 'fraudulent', 'rice', 'policy', 'strict', 'condition', 'raw', 'correctly', 'car', 'polite']"],"x":[-0.0,-12.592556501681733,-12.592556501681733,-0.0],"xaxis":"x","y":[115.0,115.0,125.0,125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["['crap', 'offer', 'tea', 'convenience', 'tata', 'new', 'lockdown', 'similar', 'provider', 'sale', 'fake', 'company', 'ad', 'impossible', 'talk']","()","()","+++: []\u003cbr\u003e---: ['shipment', 'plastic', 'utm', 'fresho', 'record', 'terrible', 'image', 'though', 'pc', 'condition', 'polite', 'however', 'lot', 'critical', 'conveyance']"],"x":[-0.0,-15.227348139044311,-15.227348139044311,-12.592556501681733],"xaxis":"x","y":[105.0,105.0,120.0,120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["['sweet', 'review', 'mobile', 'rude', 'chicken', 'piece', 'invalid', 'gift', 'r', 'interested', 'card', 'health', 'ready', 'account', 'official']","()","()","+++: []\u003cbr\u003e---: ['crap', 'offer', 'tea', 'tata', 'new', 'ad', 'lockdown', 'similar', 'provider', 'sale', 'fake', 'company', 'convenience', 'impossible', 'talk']"],"x":[-0.0,-15.409987918915862,-15.409987918915862,-15.227348139044311],"xaxis":"x","y":[95.0,95.0,112.5,112.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["['operational', 'surely', 'cancellation', 'water', 'issue', 'cake', 'instead', 'size', 'veggie', 'bottle', 'sick', 'warehouse', 'secondly', 'pizza', 'replacement']","()","()","+++: []\u003cbr\u003e---: ['sweet', 'account', 'mobile', 'review', 'rude', 'chicken', 'piece', 'invalid', 'gift', 'interested', 'card', 'health', 'ready', 'r', 'official']"],"x":[-0.0,-15.479352427104306,-15.479352427104306,-15.409987918915862],"xaxis":"x","y":[85.0,85.0,103.75,103.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["['small', 'second', 'answer', 'disappointed', 'shopping', 'food', 'grocery', 'quantity', 'website', 'bag', 'door', 'price', 'list', 'night', 'thing']","()","()","+++: []\u003cbr\u003e---: ['replacement', 'pizza', 'cancellation', 'water', 'issue', 'cake', 'instead', 'size', 'veggie', 'bottle', 'sick', 'warehouse', 'secondly', 'surely', 'operational']"],"x":[-0.0,-22.186201546513093,-22.186201546513093,-15.479352427104306],"xaxis":"x","y":[75.0,75.0,94.375,94.375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["['refund', 'old', 'bill', 'amount', 'fraud', 'care', 'different', 'phone', 'number', 'money', 'wallet', 'date', 'customer', 'email', 'executive']","()","()","+++: []\u003cbr\u003e---: ['small', 'second', 'price', 'answer', 'shopping', 'thing', 'food', 'grocery', 'quantity', 'website', 'bag', 'disappointed', 'list', 'night', 'door']"],"x":[-0.0,-26.331595190444453,-26.331595190444453,-22.186201546513093],"xaxis":"x","y":[65.0,65.0,84.6875,84.6875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["['m ...
